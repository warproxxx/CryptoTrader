# %%
#now to modify the URL.

# %load_ext autoreload
# %autoreload 2

from tweetscrapper import query_tweets
from datetime import datetime, date, timedelta
from dateutil.rrule import rrule, DAILY

import pandas as pd
import time

# %%
df = pd.DataFrame(columns=['ID', 'Tweet', 'Time', 'User', 'Likes', 'Replies', 'Retweet'])
list_of_tweets = query_tweets("Bitcoin min_retweets:1", 10, begindate=date(2015,1,1), enddate=date(2015,3,1), poolsize=10)

for tweet in list_of_tweets:
    df = df.append({'ID': tweet.id, 'Tweet': tweet.text, 'Time': tweet.timestamp, 'User': tweet.user, 'Likes': tweet.likes, 'Replies': tweet.replies, 'Retweet': tweet.retweets}, ignore_index=True)

# %%
df
# Out:
#                     ID                                              Tweet  \
# 0   568560538986217472  $241.31 ·  can't take candles too seriously ;)...
# 1   568560426507759617  The latest Bitcoin Price Index is 240.13 USD h...
# 2   568560312976162816  VICE: #ethereum smartcontracts are more disrup...
# 3   568559428544421889  Pixel Puzzles 2: Birds coming 2/20 @ 7PM CST. ...
# 4   568559387293433856  CNN Show on Bitcoin tonight at 9pm EST : Bitco...
# 5   568559352526835712  Bitcoin: TradingPub: Bitcoin - The Top Market ...
# 6   568559327528796160  DiceCoin is a modern online game using #Bitcoi...
# 7   568559297573081088  DiceCoin is a modern online game using #Bitcoi...
# 8   568559208108568576  In the last 10 mins, there were arb opps spann...
# 9   568559202056036352  #stripe now accepts #bitcoin https://stripe.co...
# 10  568559193411727360  Alış: 574.18 TL - Satış: 578.08 TL | (20-02-20...
# 11  568559079234392065  Stripe Now Accepts Bitcoin Payments / Cryptocu...
# 12  568558950561521664  Come join the tables today and everyday with #...
# 13  568558937907331072  Poker InfoThanks for the follow #askastoreaday...
# 14  568558728728989696  I know almost *nothing* about #BitCoin, but th...
# 15  568558702090825728  Accelerate your earnings Best Coin Mining Syst...
# 16  568558701101129729  Dell Expands Bitcoin Payments to UK and Canada...
# 17  568558696067784704  Accelerate your earnings.Mining Done Right.\nB...
# 18  568558685825474561  Bitcoin Price Smash Down https://www.cryptocoi...
# 19  568558679986987008  Alış: 574.1 TL - Satış: 578.08 TL | (20-02-201...
#
#                   Time             User Likes Replies Retweet
# 0  2015-02-19 23:59:30      whaleclubco     1       0       1
# 1  2015-02-19 23:59:03         coindesk     7       2      31
# 2  2015-02-19 23:58:36    pjvangarderen     3       0       1
# 3  2015-02-19 23:55:05      coinplay_io     0       0       1
# 4  2015-02-19 23:54:55     CoinEnablers     0       0       1
# 5  2015-02-19 23:54:47      Cryptogeeks     1       0       1
# 6  2015-02-19 23:54:41         DocMobGo     0       0       3
# 7  2015-02-19 23:54:34         DocMobGo     0       0       3
# 8  2015-02-19 23:54:13      ProjectCoin     1       0       3
# 9  2015-02-19 23:54:11        jalateras     1       0       2
# 10 2015-02-19 23:54:09       bitliveapp     1       0       2
# 11 2015-02-19 23:53:42        bitmakler     1       0       1
# 12 2015-02-19 23:53:11    GetLuckyPoker     1       0       1
# 13 2015-02-19 23:53:08     DOGECOINSHOP     0       0       0
# 14 2015-02-19 23:52:18          atheken     2       3       1
# 15 2015-02-19 23:52:12  cointellectmine     0       0       1
# 16 2015-02-19 23:52:12       BitcoinIRL     1       0       3
# 17 2015-02-19 23:52:11  cointellect2000     1       0       2
# 18 2015-02-19 23:52:08  CryptoCoinsNews     2       1       4
# 19 2015-02-19 23:52:07       bitliveapp     0       0       2

# %%
def scrape(start_date, end_date, keyword="Bitcoin"):
    
    for dt in rrule(DAILY, dtstart=start_date, until=end_date):
        df = pd.DataFrame(columns=['ID', 'Tweet', 'Time', 'User', 'Likes', 'Replies', 'Retweet'])
        
        yesterday = dt - timedelta(days=1)
        tomorrow = dt + timedelta(days=1)
        
        begin = yesterday.date()
        end = tomorrow.date()
        
        print("{} {}".format(begin, end))
        list_of_tweets = query_tweets("Bitcoin", 1000, begindate=begin, enddate=end, poolsize=10)

        for tweet in list_of_tweets:
            df = df.append({'ID': tweet.id, 'Tweet': tweet.text, 'Time': tweet.timestamp, 'User': tweet.user, 'Likes': tweet.likes, 'Replies': tweet.replies, 'Retweet': tweet.retweets}, ignore_index=True)

        df.to_csv("{}.csv".format(dt.strftime('%Y-%m-%d'), index=False))
        
        #if statement. If < 50 retry. Also modify the program to get top tweets

for d in range(2013, 2018):
    scrape(date(d,1,1), date(d, 12, 31))
# Out:
# 2012-12-31 2013-01-02
# 2013-01-01 2013-01-03

# %%
twitterkeywords = ['Bitcoin', 'Ethereum', 'Litecoin', 'Dogecoin', 'Ripple', 'Stellar', 'Monero']
