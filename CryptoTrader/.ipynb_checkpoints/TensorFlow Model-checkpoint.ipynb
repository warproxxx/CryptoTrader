# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from data_utils import BasicFunctions, PriceFunctions
from TechnicalAnalysis import TechnicalAnalysis 
from BackTest import Backtester, strategyBacktest
import math
import tensorflow as tf
from scipy.stats import linregress

from IPython.display import HTML

import os
from datetime import datetime

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# c:\programdata\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
bf = BasicFunctions()
pf = PriceFunctions()

# %%
coins = ['BTC', 'ETH', 'DASH', 'DOGE', 'LTC', 'STR', 'XMR', 'XRP']

# %%
dfs = {}
merged_dfs = {}

pd_Xtrains = {}
pd_ytrains = {}
pd_Xtests = {}
pd_ytests = {}

pd_Xtrains_nd = {}
pd_Xtests_nd = {}

means = {}
stds = {}

Xtrains = {}
ytrains = {}
Xtests = {}
ytests = {}


for coin in coins:
    dfs[coin] = pf.get_pandas(coin=coin, targetdays=24, absolute=True)

dfs = pf.to_same_starting(dfs)
dfs = pf.to_usd(dfs)

for coin in coins:
    ta = TechnicalAnalysis(dfs[coin], Timeframe=[24], period=[14], coin=coin)
    ta.merge_time(cache=True)

    merged_dfs[coin] = ta.get_dic()['24hour']
    

for coin in coins:
    pd_Xtrains[coin], pd_ytrains[coin], pd_Xtests[coin], pd_ytests[coin] = pf.split_traintest(merged_dfs[coin])

    pd_Xtrains_nd[coin] = pd_Xtrains[coin].drop('Date', axis=1)
    pd_Xtests_nd[coin] = pd_Xtests[coin].drop('Date', axis=1)

    means[coin], stds[coin], Xtrains[coin], ytrains[coin], Xtests[coin], ytests[coin] = pf.get_numpy(pd_Xtrains_nd[coin], pd_ytrains[coin], pd_Xtests_nd[coin], pd_ytests[coin])
# Out:
# Read from cache
# Read from cache
# Read from cache
# Read from cache
# Read from cache
# Read from cache
# Read from cache
# Read from cache

# %%
# ta = TechnicalAnalysis(df, timeframe=[3,6,12,24], period=[14, 20])
# ta.merge_time()

# ta.perform('obv')
# ta.perform('macd')
# ta.perform('bollingerband')
# ta.perform('volumechange')
# ta.perform('rsi')


# df_withta = ta.get_dataframe()
#gotta cache this too

# %%
def create_placeholders(Xshape, yshape):
    X = tf.placeholder(tf.float32, shape=(None, Xshape), name='X')
    y = tf.placeholder(tf.float32, shape=(None, yshape), name='y')
    
    return X,y

# %%
def forward_propagation(X, training):
    Z1 = tf.layers.dense(X, 30, name='Z1', kernel_initializer=tf.keras.initializers.he_normal(seed=1))
    bn1 = tf.layers.batch_normalization(Z1, training=training, name='bn1')
    ac1 = tf.nn.relu(bn1, name='ac1')
    A1 = tf.layers.dropout(ac1, 0.3, name='A1')
    
    Z2 = tf.layers.dense(A1, 15, name='Z2', kernel_initializer=tf.keras.initializers.he_normal(seed=1))
    bn2 = tf.layers.batch_normalization(Z2, training=training, name='bn2')
    ac2 = tf.nn.relu(bn2, name='ac2')
    A2 = tf.layers.dropout(ac2, 0.3, name='A2')
    
    Z3 = tf.layers.dense(A2, 2, name='Z3', kernel_initializer=tf.keras.initializers.he_normal(seed=1))
    #A3 = tf.nn.relu(Z3)

    return Z3

# %%
def cost_function(AL, y):
    classcost = tf.reduce_mean(tf.square(y[:, 0] - AL[:, 0]))
    percost = tf.reduce_mean(tf.square(y[:, 1] - AL[:, 1]))
    
    classification  = tf.abs(tf.log(classcost))
    regression = tf.abs(tf.log(percost))
    
    cost = 0.5 * classification + 5 * regression
    
    costs = [cost, classification, regression]
    
    return costs

# %%
def neuralNetwork(Xtrain, ytrain, Xtest, ytest, coin, batchsize=32):
    cwd = os.getcwd()

    now = datetime.utcnow().strftime("%Y%m%d%H%M%S")
    root_logdir = "tf_logs"
    logdir = "{}/run-{}/".format(root_logdir, now)
    
    tf.reset_default_graph()

    with tf.name_scope('Initialize'):
        X, y = create_placeholders(Xtrain.shape[1], 2)
        training = tf.placeholder(tf.bool, shape=(), name='training')

    with tf.name_scope('ForwardPropagation'):
        ALtensor = forward_propagation(X, training)

    with tf.name_scope('CostFunction'):
        cost = cost_function(ALtensor, ytrain)

    with tf.name_scope('BackPropagation'):
        optimizer = tf.train.AdamOptimizer(learning_rate=0.005).minimize(cost[0])

    init = tf.global_variables_initializer()

    cost_summary = tf.summary.scalar('Cost', cost[0])
    file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())

    costs = []

    with tf.Session() as sess:
        sess.run(init)
        mini_batches = bf.initialize_mini_batch(Xtrain, ytrain, batchsize=batchsize)

        for i in range(1000):
            for batch in mini_batches:
                (Xbatch, ybatch) = batch
                sess.run(optimizer, feed_dict={X: Xbatch, y: ybatch, training: True})

            if (i % 50 == 0):
                cost_str = cost_summary.eval(feed_dict={X: Xbatch, y: ybatch, training: True})

                cost0 = cost[0].eval(feed_dict={X: Xbatch, y: ybatch, training: True})
                cost1 = cost[1].eval(feed_dict={X: Xbatch, y: ybatch, training: True})
                cost2 = cost[2].eval(feed_dict={X: Xbatch, y: ybatch, training: True})

                costs.append(cost0)

                print("Iteration: {}\nClassification cost: {}\nRegression cost: {}\nTotal Clost: {}\n\n".format(i, cost0, cost1, cost2))

                file_writer.add_summary(cost_str, i)


        saver = tf.train.Saver()
        
        sessiondir = cwd + '/tf_logs/session/session-{}.chkp'.format(coin)

        saver.save(sess, sessiondir)
        file_writer.close()

    bf.single_plot(costs, log=False)
    
    return sessiondir

# %%
sessiondirs = {}
Xtensors = {}
ALtensors = {}
trainings = {}

for coin in coins:
    sessiondirs[coin] = neuralNetwork(Xtrains[coin], ytrains[coin], Xtests[coin], ytests[coin], coin)
# Out:
# Iteration: 0
# Classification cost: 0.903346836566925
# Regression cost: 0.06962472945451736
# Total Clost: 0.17370688915252686
#
#
# Iteration: 50
# Classification cost: 0.09636539220809937
# Regression cost: 0.016976045444607735
# Total Clost: 0.017575474455952644
#
#
# Iteration: 100
# Classification cost: 0.08575408160686493
# Regression cost: 0.002070189919322729
# Total Clost: 0.0169437974691391
#
#
# Iteration: 150
# Classification cost: 0.05528151988983154
# Regression cost: 0.012593136169016361
# Total Clost: 0.0097969900816679
#
#
# Iteration: 200
# Classification cost: 0.06503427773714066
# Regression cost: 0.001099177054129541
# Total Clost: 0.012896937318146229
#
#
# Iteration: 250
# Classification cost: 0.15209418535232544
# Regression cost: 0.01128763984888792
# Total Clost: 0.029290074482560158
#
#
# Iteration: 300
# Classification cost: 0.019402144476771355
# Regression cost: 0.0033286185935139656
# Total Clost: 0.0035475671757012606
#
#
# Iteration: 350
# Classification cost: 0.02680906280875206
# Regression cost: 0.011109166778624058
# Total Clost: 0.004250896163284779
#
#
# Iteration: 400
# Classification cost: 0.15451675653457642
# Regression cost: 0.016785338521003723
# Total Clost: 0.02922481670975685
#
#
# Iteration: 450
# Classification cost: 0.0368138924241066
# Regression cost: 0.0007393010891973972
# Total Clost: 0.007288848515599966
#
#
# Iteration: 500
# Classification cost: 0.03515533357858658
# Regression cost: 0.002623360138386488
# Total Clost: 0.0067687309347093105
#
#
# Iteration: 550
# Classification cost: 0.11456437408924103
# Regression cost: 0.0016798173310235143
# Total Clost: 0.02274489216506481
#
#
# Iteration: 600
# Classification cost: 0.06567765772342682
# Regression cost: 0.0009467886411584914
# Total Clost: 0.013040851801633835
#
#
# Iteration: 650
# Classification cost: 0.1501215696334839
# Regression cost: 0.004463426303118467
# Total Clost: 0.029577970504760742
#
#
# Iteration: 700
# Classification cost: 0.06343845278024673
# Regression cost: 0.0009672730811871588
# Total Clost: 0.012590962462127209
#
#
# Iteration: 750
# Classification cost: 0.049580011516809464
# Regression cost: 0.007728202268481255
# Total Clost: 0.009143182076513767
#
#
# Iteration: 800
# Classification cost: 0.07194563746452332
# Regression cost: 0.000891248055268079
# Total Clost: 0.014300002716481686
#
#
# Iteration: 850
# Classification cost: 0.12365466356277466
# Regression cost: 0.002349273068830371
# Total Clost: 0.024496005848050117
#
#
# Iteration: 900
# Classification cost: 0.14086943864822388
# Regression cost: 0.010048158466815948
# Total Clost: 0.02716907300055027
#
#
# Iteration: 950
# Classification cost: 0.02548324316740036
# Regression cost: 0.021742159500718117
# Total Clost: 0.002922432729974389
#
#
# Iteration: 0
# Classification cost: 0.7984620332717896
# Regression cost: 0.07901879400014877
# Total Clost: 0.1517905294895172
#
#
# Iteration: 50
# Classification cost: 0.08082601428031921
# Regression cost: 0.019178621470928192
# Total Clost: 0.014247341081500053
#
#
# Iteration: 100
# Classification cost: 0.00915763434022665
# Regression cost: 0.007336161565035582
# Total Clost: 0.0010979106882587075
#
#
# Iteration: 150
# Classification cost: 0.03170033544301987
# Regression cost: 0.003233920084312558
# Total Clost: 0.006016675382852554
#
#
# Iteration: 200
# Classification cost: 0.026249706745147705
# Regression cost: 0.01349520031362772
# Total Clost: 0.0039004215504974127
#
#
# Iteration: 250
# Classification cost: 0.0048875967040658
# Regression cost: 0.005498879123479128
# Total Clost: 0.00042763148667290807
#
#
# Iteration: 300
# Classification cost: 0.15604348480701447
# Regression cost: 0.011435085907578468
# Total Clost: 0.03006518818438053
#
#
# Iteration: 350
# Classification cost: 0.026390593498945236
# Regression cost: 0.0066422391682863235
# Total Clost: 0.0046138945035636425
#
#
# Iteration: 400
# Classification cost: 0.008485347963869572
# Regression cost: 0.0020643905736505985
# Total Clost: 0.0014906305586919188
#
#
# Iteration: 450
# Classification cost: 0.017961695790290833
# Regression cost: 0.005266483407467604
# Total Clost: 0.003065690863877535
#
#
# Iteration: 500
# Classification cost: 0.03497143089771271
# Regression cost: 0.014146740548312664
# Total Clost: 0.0055796122178435326
#
#
# Iteration: 550
# Classification cost: 0.041003406047821045
# Regression cost: 0.013448123820126057
# Total Clost: 0.006855868734419346
#
#
# Iteration: 600
# Classification cost: 0.05694375932216644
# Regression cost: 0.010733001865446568
# Total Clost: 0.01031545177102089
#
#
# Iteration: 650
# Classification cost: 0.01870274916291237
# Regression cost: 0.017911145463585854
# Total Clost: 0.001949435449205339
#
#
# Iteration: 700
# Classification cost: 0.019642384722828865
# Regression cost: 0.021004613488912582
# Total Clost: 0.0018280156655237079
#
#
# Iteration: 750
# Classification cost: 0.06888290494680405
# Regression cost: 0.011172708123922348
# Total Clost: 0.012659309431910515
#
#
# Iteration: 800
# Classification cost: 0.06654372066259384
# Regression cost: 0.01988336443901062
# Total Clost: 0.011320407502353191
#
#
# Iteration: 850
# Classification cost: 0.005565127357840538
# Regression cost: 0.007516368292272091
# Total Clost: 0.0003613886365201324
#
#
# Iteration: 900
# Classification cost: 0.019481107592582703
# Regression cost: 0.019788701087236404
# Total Clost: 0.0019173513865098357
#
#
# Iteration: 950
# Classification cost: 0.05452480539679527
# Regression cost: 0.0015814285725355148
# Total Clost: 0.010746818035840988
#
#
# Iteration: 0
# Classification cost: 0.3550565242767334
# Regression cost: 0.14589601755142212
# Total Clost: 0.05642170459032059
#
#
# Iteration: 50
# Classification cost: 0.10595396906137466
# Regression cost: 0.001313776709139347
# Total Clost: 0.021059416234493256
#
#
# Iteration: 100
# Classification cost: 0.0504370741546154
# Regression cost: 0.0025902530178427696
# Total Clost: 0.009828389622271061
#
#
# Iteration: 150
# Classification cost: 0.024699034169316292
# Regression cost: 0.021413907408714294
# Total Clost: 0.0027984161861240864
#
#
# Iteration: 200
# Classification cost: 0.08792158216238022
# Regression cost: 0.013118525967001915
# Total Clost: 0.016272464767098427
#
#
# Iteration: 250
# Classification cost: 0.07144410163164139
# Regression cost: 0.011305555701255798
# Total Clost: 0.013158264569938183
#
#
# Iteration: 300
# Classification cost: 0.1527131348848343
# Regression cost: 0.006524214521050453
# Total Clost: 0.029890207573771477
#
#
# Iteration: 350
# Classification cost: 0.01481649186462164
# Regression cost: 0.003549467772245407
# Total Clost: 0.002608351642265916
#
#
# Iteration: 400
# Classification cost: 0.07220844179391861
# Regression cost: 0.009342878125607967
# Total Clost: 0.013507400639355183
#
#
# Iteration: 450
# Classification cost: 0.16945886611938477
# Regression cost: 0.01663387194275856
# Total Clost: 0.032228387892246246
#
#
# Iteration: 500
# Classification cost: 0.06778967380523682
# Regression cost: 0.011828184127807617
# Total Clost: 0.012375117279589176
#
#
# Iteration: 550
# Classification cost: 0.10520722717046738
# Regression cost: 0.0038334797136485577
# Total Clost: 0.02065809816122055
#
#
# Iteration: 600
# Classification cost: 0.0735013410449028
# Regression cost: 0.009563819505274296
# Total Clost: 0.013743886724114418
#
#
# Iteration: 650
# Classification cost: 0.06844792515039444
# Regression cost: 0.003078961046412587
# Total Clost: 0.013381687924265862
#
#
# Iteration: 700
# Classification cost: 0.14065200090408325
# Regression cost: 0.010800783522427082
# Total Clost: 0.02705032378435135
#
#
# Iteration: 750
# Classification cost: 0.01553189568221569
# Regression cost: 0.004494327586144209
# Total Clost: 0.002656946424394846
#
#
# Iteration: 800
# Classification cost: 0.06754062324762344
# Regression cost: 0.01630006544291973
# Total Clost: 0.0118781179189682
#
#
# Iteration: 850
# Classification cost: 0.03187280148267746
# Regression cost: 0.0182279534637928
# Total Clost: 0.004551764577627182
#
#
# Iteration: 900
# Classification cost: 0.02344432845711708
# Regression cost: 0.006145864725112915
# Total Clost: 0.004074279218912125
#
#
# Iteration: 950
# Classification cost: 0.047842420637607574
# Regression cost: 0.010800241492688656
# Total Clost: 0.008488459512591362
#
#
# Iteration: 0
# Classification cost: 1.3045891523361206
# Regression cost: 0.016420332714915276
# Total Clost: 0.25927579402923584
#
#
# Iteration: 50
# Classification cost: 0.03974321857094765
# Regression cost: 0.008349188603460789
# Total Clost: 0.007113724946975708
#
#
# Iteration: 100
# Classification cost: 0.21672575175762177
# Regression cost: 0.0004804172203876078
# Total Clost: 0.04329710826277733
#
#
# Iteration: 150
# Classification cost: 0.12070787698030472
# Regression cost: 0.006885036360472441
# Total Clost: 0.02345307171344757
# Iteration: 200
# Classification cost: 0.14138677716255188
# Regression cost: 0.010610646568238735
# Total Clost: 0.027216291055083275
#
#
# Iteration: 250
# Classification cost: 0.03254925459623337
# Regression cost: 0.019508473575115204
# Total Clost: 0.004559003282338381
#
#
# Iteration: 300
# Classification cost: 0.07181686908006668
# Regression cost: 0.011873523704707623
# Total Clost: 0.013176021166145802
#
#
# Iteration: 350
# Classification cost: 0.1718682497739792
# Regression cost: 0.0019077366450801492
# Total Clost: 0.03418287634849548
#
#
# Iteration: 400
# Classification cost: 0.08077406138181686
# Regression cost: 0.0042059533298015594
# Total Clost: 0.015734216198325157
#
#
# Iteration: 450
# Classification cost: 0.0748388022184372
# Regression cost: 0.004577667452394962
# Total Clost: 0.014509993605315685
#
#
# Iteration: 500
# Classification cost: 0.014113008975982666
# Regression cost: 0.001047504018060863
# Total Clost: 0.0027178514283150434
#
#
# Iteration: 550
# Classification cost: 0.07351010292768478
# Regression cost: 0.004095286130905151
# Total Clost: 0.014292491599917412
#
#
# Iteration: 600
# Classification cost: 0.08515726029872894
# Regression cost: 0.015154106542468071
# Total Clost: 0.015516041778028011
#
#
# Iteration: 650
# Classification cost: 0.08612934499979019
# Regression cost: 0.0037078370805829763
# Total Clost: 0.016855085268616676
#
#
# Iteration: 700
# Classification cost: 0.01679077558219433
# Regression cost: 0.02046283334493637
# Total Clost: 0.001311871805228293
#
#
# Iteration: 750
# Classification cost: 0.00838021282106638
# Regression cost: 0.01340113952755928
# Total Clost: 0.0003359285765327513
#
#
# Iteration: 800
# Classification cost: 0.045088063925504684
# Regression cost: 0.005873610731214285
# Total Clost: 0.008430251851677895
#
#
# Iteration: 850
# Classification cost: 0.03743791952729225
# Regression cost: 0.0004391442344058305
# Total Clost: 0.007443669252097607
#
#
# Iteration: 900
# Classification cost: 0.04982312396168709
# Regression cost: 0.006209959741681814
# Total Clost: 0.009343628771603107
#
#
# Iteration: 950
# Classification cost: 0.06985368579626083
# Regression cost: 0.009122359566390514
# Total Clost: 0.013058501295745373
#
#
# Iteration: 0
# Classification cost: 0.7642887830734253
# Regression cost: 0.20887058973312378
# Total Clost: 0.13197070360183716
#
#
# Iteration: 50
# Classification cost: 0.1355268955230713
# Regression cost: 0.004533964209258556
# Total Clost: 0.026651980355381966
#
#
# Iteration: 100
# Classification cost: 0.03181027993559837
# Regression cost: 0.001741322805173695
# Total Clost: 0.006187923718243837
#
#
# Iteration: 150
# Classification cost: 0.0212758406996727
# Regression cost: 0.018998607993125916
# Total Clost: 0.0023553073406219482
#
#
# Iteration: 200
# Classification cost: 0.04748263582587242
# Regression cost: 0.007303680758923292
# Total Clost: 0.008766159415245056
#
#
# Iteration: 250
# Classification cost: 0.035081058740615845
# Regression cost: 0.0017938013188540936
# Total Clost: 0.006836831569671631
#
#
# Iteration: 300
# Classification cost: 0.07906866073608398
# Regression cost: 0.007965375669300556
# Total Clost: 0.015017195604741573
#
#
# Iteration: 350
# Classification cost: 0.08115849643945694
# Regression cost: 0.05353274196386337
# Total Clost: 0.01087842509150505
#
#
# Iteration: 400
# Classification cost: 0.018257489427924156
# Regression cost: 0.0047271400690078735
# Total Clost: 0.0031787839252501726
#
#
# Iteration: 450
# Classification cost: 0.0148666612803936
# Regression cost: 0.0007317964336834848
# Total Clost: 0.002900152700021863
#
#
# Iteration: 500
# Classification cost: 0.03554515913128853
# Regression cost: 0.010165583342313766
# Total Clost: 0.006092473398894072
#
#
# Iteration: 550
# Classification cost: 0.09959527850151062
# Regression cost: 0.000749570841435343
# Total Clost: 0.019844098016619682
#
#
# Iteration: 600
# Classification cost: 0.04548689350485802
# Regression cost: 0.007778946775943041
# Total Clost: 0.008319484069943428
#
#
# Iteration: 650
# Classification cost: 0.06207813695073128
# Regression cost: 0.00785630289465189
# Total Clost: 0.011629996821284294
#
#
# Iteration: 700
# Classification cost: 0.08555451035499573
# Regression cost: 0.0079609714448452
# Total Clost: 0.016314804553985596
#
#
# Iteration: 750
# Classification cost: 0.04078153520822525
# Regression cost: 0.0056923809461295605
# Total Clost: 0.007587069179862738
#
#
# Iteration: 800
# Classification cost: 0.037141360342502594
# Regression cost: 0.010621790774166584
# Total Clost: 0.006366092711687088
#
#
# Iteration: 850
# Classification cost: 0.011093487963080406
# Regression cost: 0.0034577602054923773
# Total Clost: 0.001872921478934586
#
#
# Iteration: 900
# Classification cost: 0.02510199137032032
# Regression cost: 0.0039901891723275185
# Total Clost: 0.004621379543095827
#
#
# Iteration: 950
# Classification cost: 0.047641802579164505
# Regression cost: 0.01088950876146555
# Total Clost: 0.008439409546554089
#
#
# Iteration: 0
# Classification cost: 1.6593760251998901
# Regression cost: 0.09952416270971298
# Total Clost: 0.32192277908325195
#
#
# Iteration: 50
# Classification cost: 0.12533041834831238
# Regression cost: 0.009892012923955917
# Total Clost: 0.024076882749795914
#
#
# Iteration: 100
# Classification cost: 0.123517706990242
# Regression cost: 0.005681911949068308
# Total Clost: 0.024135349318385124
#
#
# Iteration: 150
# Classification cost: 0.0535254068672657
# Regression cost: 0.007053276523947716
# Total Clost: 0.009999753907322884
#
#
# Iteration: 200
# Classification cost: 0.16537357866764069
# Regression cost: 0.005282561760395765
# Total Clost: 0.03254646062850952
#
#
# Iteration: 250
# Classification cost: 0.05968651920557022
# Regression cost: 0.005346642341464758
# Total Clost: 0.01140263956040144
#
#
# Iteration: 300
# Classification cost: 0.08461259305477142
# Regression cost: 0.003475460922345519
# Total Clost: 0.016574973240494728
#
#
# Iteration: 350
# Classification cost: 0.08783802390098572
# Regression cost: 0.000873291224706918
# Total Clost: 0.01748027466237545
#
#
# Iteration: 400
# Classification cost: 0.07025457918643951
# Regression cost: 0.0027148588560521603
# Total Clost: 0.013779430650174618
#
#
# Iteration: 450
# Classification cost: 0.06207228824496269
# Regression cost: 0.007402752060443163
# Total Clost: 0.011674182489514351
#
#
# Iteration: 500
# Classification cost: 0.07370356470346451
# Regression cost: 0.008590295910835266
# Total Clost: 0.013881683349609375
#
#
# Iteration: 550
# Classification cost: 0.0970582440495491
# Regression cost: 0.0038887844420969486
# Total Clost: 0.01902277022600174
#
#
# Iteration: 600
# Classification cost: 0.027001896873116493
# Regression cost: 0.003948512487113476
# Total Clost: 0.0050055282190442085
#
#
# Iteration: 650
# Classification cost: 0.0389852300286293
# Regression cost: 0.008827853947877884
# Total Clost: 0.0069142603315413
#
#
# Iteration: 700
# Classification cost: 0.04931563884019852
# Regression cost: 0.02002212591469288
# Total Clost: 0.00786091573536396
#
#
# Iteration: 750
# Classification cost: 0.0868481993675232
# Regression cost: 0.0028975822497159243
# Total Clost: 0.017079882323741913
#
#
# Iteration: 800
# Classification cost: 0.028324585407972336
# Regression cost: 0.0005128260818310082
# Total Clost: 0.005613634362816811
#
#
# Iteration: 850
# Classification cost: 0.019824720919132233
# Regression cost: 0.004737734328955412
# Total Clost: 0.0034911707043647766
#
#
# Iteration: 900
# Classification cost: 0.07765121757984161
# Regression cost: 0.0004107007116544992
# Total Clost: 0.015489173121750355
#
#
# Iteration: 950
# Classification cost: 0.03822417929768562
# Regression cost: 0.00590658700093627
# Total Clost: 0.007054176647216082
#
#
# Iteration: 0
# Classification cost: 0.9580623507499695
# Regression cost: 0.203961580991745
# Total Clost: 0.17121630907058716
#
#
# Iteration: 50
# Classification cost: 0.05432102084159851
# Regression cost: 0.008641939610242844
# Total Clost: 0.010000010021030903
#
#
# Iteration: 100
# Classification cost: 0.041121434420347214
# Regression cost: 0.0162182804197073
# Total Clost: 0.006602458655834198
#
#
# Iteration: 150
# Classification cost: 0.01647801138460636
# Regression cost: 0.012045941315591335
# Total Clost: 0.002091008238494396
#
#
# Iteration: 200
# Classification cost: 0.01107056438922882
# Regression cost: 0.004808823578059673
# Total Clost: 0.001733230659738183
#
#
# Iteration: 250
# Classification cost: 0.06158990040421486
# Regression cost: 0.007597445044666529
# Total Clost: 0.011558235622942448
#
#
# Iteration: 300
# Classification cost: 0.11967950314283371
# Regression cost: 0.011957143433392048
# Total Clost: 0.022740187123417854
#
#
# Iteration: 350
# Classification cost: 0.18437477946281433
# Regression cost: 0.010725049301981926
# Total Clost: 0.0358024500310421
# Iteration: 400
# Classification cost: 0.07328388839960098
# Regression cost: 0.001260201446712017
# Total Clost: 0.014530756510794163
#
#
# Iteration: 450
# Classification cost: 0.17892619967460632
# Regression cost: 0.0029255584813654423
# Total Clost: 0.035492684692144394
#
#
# Iteration: 500
# Classification cost: 0.05476634204387665
# Regression cost: 0.02887372300028801
# Total Clost: 0.008065896108746529
#
#
# Iteration: 550
# Classification cost: 0.07190124690532684
# Regression cost: 0.013844638131558895
# Total Clost: 0.012995785102248192
#
#
# Iteration: 600
# Classification cost: 0.014257132075726986
# Regression cost: 0.0021941415034234524
# Total Clost: 0.0026320121251046658
#
#
# Iteration: 650
# Classification cost: 0.07634436339139938
# Regression cost: 0.0035126437433063984
# Total Clost: 0.014917607419192791
#
#
# Iteration: 700
# Classification cost: 0.047623198479413986
# Regression cost: 0.014361496083438396
# Total Clost: 0.0080884899944067
#
#
# Iteration: 750
# Classification cost: 0.044447194784879684
# Regression cost: 0.003212480340152979
# Total Clost: 0.008568190969526768
#
#
# Iteration: 800
# Classification cost: 0.020357104018330574
# Regression cost: 0.002171786967664957
# Total Clost: 0.003854242153465748
#
#
# Iteration: 850
# Classification cost: 0.05484337359666824
# Regression cost: 0.009068491868674755
# Total Clost: 0.01006182562559843
#
#
# Iteration: 900
# Classification cost: 0.022907404229044914
# Regression cost: 0.003353331470862031
# Total Clost: 0.004246147815138102
#
#
# Iteration: 950
# Classification cost: 0.030241074040532112
# Regression cost: 0.005854956805706024
# Total Clost: 0.00546271912753582
#
#
# Iteration: 0
# Classification cost: 0.893139123916626
# Regression cost: 0.15375229716300964
# Total Clost: 0.163252592086792
#
#
# Iteration: 50
# Classification cost: 0.22862668335437775
# Regression cost: 0.0004237596003804356
# Total Clost: 0.045682959258556366
#
#
# Iteration: 100
# Classification cost: 0.059684447944164276
# Regression cost: 0.016774436458945274
# Total Clost: 0.010259445756673813
#
#
# Iteration: 150
# Classification cost: 0.04392387345433235
# Regression cost: 0.013343439437448978
# Total Clost: 0.007450431119650602
#
#
# Iteration: 200
# Classification cost: 0.13830241560935974
# Regression cost: 0.00048685140791349113
# Total Clost: 0.02761179953813553
#
#
# Iteration: 250
# Classification cost: 0.16552112996578217
# Regression cost: 0.010147292166948318
# Total Clost: 0.03208949416875839
#
#
# Iteration: 300
# Classification cost: 0.06685443222522736
# Regression cost: 0.03500238433480263
# Total Clost: 0.009870648384094238
#
#
# Iteration: 350
# Classification cost: 0.04727162420749664
# Regression cost: 0.017391357570886612
# Total Clost: 0.0077151888981461525
#
#
# Iteration: 400
# Classification cost: 0.04311393201351166
# Regression cost: 0.010437190532684326
# Total Clost: 0.0075790672563016415
#
#
# Iteration: 450
# Classification cost: 0.08009647578001022
# Regression cost: 0.007111443672329187
# Total Clost: 0.01530815102159977
#
#
# Iteration: 500
# Classification cost: 0.12305701524019241
# Regression cost: 0.01037140004336834
# Total Clost: 0.023574262857437134
#
#
# Iteration: 550
# Classification cost: 0.04118974879384041
# Regression cost: 0.0030814153142273426
# Total Clost: 0.007929807528853416
#
#
# Iteration: 600
# Classification cost: 0.029561666771769524
# Regression cost: 0.0074416035786271095
# Total Clost: 0.005168172996491194
#
#
# Iteration: 650
# Classification cost: 0.07061900198459625
# Regression cost: 0.009414083324372768
# Total Clost: 0.013182392343878746
#
#
# Iteration: 700
# Classification cost: 0.10610059648752213
# Regression cost: 0.010317860171198845
# Total Clost: 0.020188333466649055
#
#
# Iteration: 750
# Classification cost: 0.08269510418176651
# Regression cost: 0.008269947953522205
# Total Clost: 0.01571202650666237
#
#
# Iteration: 800
# Classification cost: 0.055321626365184784
# Regression cost: 0.013579610735177994
# Total Clost: 0.009706364013254642
#
#
# Iteration: 850
# Classification cost: 0.07700908929109573
# Regression cost: 0.01026127953082323
# Total Clost: 0.014375690370798111
#
#
# Iteration: 900
# Classification cost: 0.04769432172179222
# Regression cost: 0.0056619890965521336
# Total Clost: 0.008972665295004845
#
#
# Iteration: 950
# Classification cost: 0.014152999967336655
# Regression cost: 0.0021190429106354713
# Total Clost: 0.00261869584210217

# %%
def sigmoid(Z):
    return (1/(1+np.exp(-Z)))

def calculate_accuracy(AL, y):
    #calculate accuracy, precision, recall and F1 value here too
    ALc = AL[:, 0]
    yc = y[:, 0]
    
    ALc = ALc > 0.5
    ALc = ALc.astype(int)
    
    total = ALc.shape[0]
    
    TP = np.sum(np.logical_and(ALc==1, yc==1))
    TN = np.sum(np.logical_and(ALc==0, yc==0))
    
    FP = np.sum(np.logical_and(ALc==1, yc==0))
    FN = np.sum(np.logical_and(ALc==0, yc==1))
    
    P = TP / (TP + FP)
    R = TP / (TP + TN)
    F1 = (2 * P * R) / (P + R)
    
    
    acc = np.sum(ALc == yc)/total
    
    
    print("\nAccuracy: {} \n".format(acc))
    print("True Positive: {} \nTrue Negative: {}\nFalse Positive: {} \nFalse Negative: {}\n".format(TP, TN, FP, FN))
    print("Precision: {} \nRecall: {} \nF1 Score: {}\n".format(P, R, F1))
    
    
    ALcr = AL[:, 1]
    ycr = y[:, 1]

    fig, axes = plt.subplots(figsize=(12,6))
    axes.plot(ALcr, label="Predicted Value")
    axes.plot(ycr, label="Actual Value")
    axes.set_ylabel("Percentage Change")
    axes.set_title("Regression Comparision")
    axes.legend(loc=4)
    
    slope, intercept, rval, pval, stderr = linregress(ycr, ALcr)
    print("R-Value: " + str(rval)) #rvalue is between -1 and 1 and can be used for single. Suitable for my purpose. R2 can be used for multiple, gives one and zero
    
    maximum = max(ycr.max(),AL.max())
    minimum = min(ycr.min(),ALcr.min())
    fig2, ax2 = plt.subplots(figsize=(12,6))
    ax2.scatter(ycr,ALcr)
    ax2.plot([minimum, maximum], [minimum, maximum], 'r-', lw=2)
    
    return AL

# %%
def calc_metrics(Xval, yval, sessiondir):
    
    tf.reset_default_graph()
    
    
    with tf.Session() as sess:
        saver = tf.train.import_meta_graph(sessiondir + ".meta")
        saver.restore(sess, sessiondir)
        
        graph = tf.get_default_graph()

        Xtensor = graph.get_tensor_by_name("Initialize/X:0")
        training = graph.get_tensor_by_name("Initialize/training:0")
        ALtensor = graph.get_tensor_by_name("ForwardPropagation/Z3/BiasAdd:0") #gotta load this shit somehow
        

        Z = sess.run(ALtensor, feed_dict={Xtensor: Xval, training: False})
        Z[:, 0] = sigmoid(Z[:, 0])

        AL = calculate_accuracy(Z, yval)
        
    return AL

# %%
ALtrains = {}

for coin in coins:
    ALtrains[coin] = calc_metrics(Xtrains[coin], ytrains[coin], sessiondirs[coin])
    print()
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-BTC.chkp
#
# Accuracy: 0.5268542199488491
#
# True Positive: 339
# True Negative: 73
# False Positive: 262
# False Negative: 108
#
# Precision: 0.5640599001663894
# Recall: 0.8228155339805825
# F1 Score: 0.6692991115498519
#
# R-Value: 0.04101519310941737
#
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-ETH.chkp
#
# Accuracy: 0.46675191815856776
#
# True Positive: 337
# True Negative: 28
# False Positive: 396
# False Negative: 21
#
# Precision: 0.4597544338335607
# Recall: 0.9232876712328767
# F1 Score: 0.6138433515482695
#
# R-Value: -0.0018449428177075284
#
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-DASH.chkp
#
# Accuracy: 0.4782608695652174
#
# True Positive: 294
# True Negative: 80
# False Positive: 329
# False Negative: 79
#
# Precision: 0.47191011235955055
# Recall: 0.786096256684492
# F1 Score: 0.5897693079237712
#
# R-Value: 0.006148060227571925
#
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-DOGE.chkp
#
# Accuracy: 0.6202046035805626
#
# True Positive: 407
# True Negative: 78
# False Positive: 228
# False Negative: 69
#
# Precision: 0.6409448818897637
# Recall: 0.8391752577319588
# F1 Score: 0.7267857142857144
#
# R-Value: -0.10018760756796248
#
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-LTC.chkp
#
# Accuracy: 0.47058823529411764
#
# True Positive: 239
# True Negative: 129
# False Positive: 319
# False Negative: 95
#
# Precision: 0.4283154121863799
# Recall: 0.6494565217391305
# F1 Score: 0.5161987041036716
#
# R-Value: 0.16826158150994683
#
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-STR.chkp
#
# Accuracy: 0.5281329923273658
#
# True Positive: 3
# True Negative: 410
# False Positive: 3
# False Negative: 366
#
# Precision: 0.5
# Recall: 0.007263922518159807
# F1 Score: 0.014319809069212413
#
# R-Value: 0.34017371297082327
#
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-XMR.chkp
#
# Accuracy: 0.4884910485933504
#
# True Positive: 267
# True Negative: 115
# False Positive: 317
# False Negative: 83
#
# Precision: 0.4571917808219178
# Recall: 0.6989528795811518
# F1 Score: 0.5527950310559006
#
# R-Value: 0.050833736037702165
#
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-XRP.chkp
#
# Accuracy: 0.5601023017902813
#
# True Positive: 10
# True Negative: 428
# False Positive: 12
# False Negative: 332
#
# Precision: 0.45454545454545453
# Recall: 0.0228310502283105
# F1 Score: 0.043478260869565216
#
# R-Value: 0.2438830729689452

# %%
ALtests = {}

for coin in coins:
    ALtests[coin] = calc_metrics(Xtests[coin], ytests[coin], sessiondirs[coin])
    print()
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-BTC.chkp
# c:\programdata\anaconda3\lib\site-packages\ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in long_scalars
# Accuracy: 0.40372670807453415
#
# True Positive: 0
# True Negative: 65
# False Positive: 0
# False Negative: 96
#
# Precision: nan
# Recall: 0.0
# F1 Score: nan
#
# R-Value: 0.11759269623542322
#
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-ETH.chkp
#
# Accuracy: 0.5279503105590062
#
# True Positive: 10
# True Negative: 75
# False Positive: 12
# False Negative: 64
#
# Precision: 0.45454545454545453
# Recall: 0.11764705882352941
# F1 Score: 0.1869158878504673
#
# R-Value: -0.0855473659534914
#
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-DASH.chkp
#
# Accuracy: 0.5590062111801242
#
# True Positive: 0
# True Negative: 90
# False Positive: 0
# False Negative: 71
#
# Precision: nan
# Recall: 0.0
# F1 Score: nan
#
# R-Value: -0.1031800606626261
#
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-DOGE.chkp
#
# Accuracy: 0.45962732919254656
#
# True Positive: 0
# True Negative: 74
# False Positive: 0
# False Negative: 87
#
# Precision: nan
# Recall: 0.0
# F1 Score: nan
#
# R-Value: 0.13480184291587247
#
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-LTC.chkp
#
# Accuracy: 0.5714285714285714
#
# True Positive: 0
# True Negative: 92
# False Positive: 0
# False Negative: 69
#
# Precision: nan
# Recall: 0.0
# F1 Score: nan
#
# R-Value: -0.04220164110018317
#
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-STR.chkp
#
# Accuracy: 0.5279503105590062
#
# True Positive: 0
# True Negative: 85
# False Positive: 0
# False Negative: 76
#
# Precision: nan
# Recall: 0.0
# F1 Score: nan
#
# R-Value: -0.13234073794913845
#
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-XMR.chkp
#
# Accuracy: 0.577639751552795
#
# True Positive: 0
# True Negative: 93
# False Positive: 0
# False Negative: 68
#
# Precision: nan
# Recall: 0.0
# F1 Score: nan
#
# R-Value: -0.08008897054530931
#
# INFO:tensorflow:Restoring parameters from C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor/tf_logs/session/session-XRP.chkp
#
# Accuracy: 0.5838509316770186
#
# True Positive: 0
# True Negative: 94
# False Positive: 0
# False Negative: 67
#
# Precision: nan
# Recall: 0.0
# F1 Score: nan
#
# R-Value: 0.04476424434812436

# %%
def perform_backtest(pd_Xtrains, pd_ytrains, ALtrains):
    
    bars = {}
    
    for key in pd_Xtrains:
        ytrain_temp = pd_ytrains[key].reset_index(drop=True)
        bars[key] = pd.concat([pd_Xtrains[key], ytrain_temp], axis=1)
    

    signals = ALtrains
    
    tbars = {}
    tsignals = {}
    
    tbars['BTC'] = bars['BTC']
    tbars['LTC'] = bars['LTC']
    tbars['ETH'] = bars['ETH']
    tbars['DASH'] = bars['DASH']
    
    tsignals['BTC'] = signals['BTC']
    tsignals['LTC'] = signals['LTC']
    tsignals['ETH'] = signals['ETH']
    tsignals['DASH'] = signals['DASH']
    
    #There is some error in the loop in backtest engine.
    
    bt = Backtester(tbars, tsignals, comission=0.1, maxper=0.01) #bars should contain 
    bt.perform_backtest()
    positions = bt.get_positions()
    bt.get_outcome()

# %%
perform_backtest(pd_Xtrains, pd_ytrains, ALtrains)
# Out:
# C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor\BackTest\backtester.py:227: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   requiredcoins = closingsignals[self.positions['Coin'] == coin]
# C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor\BackTest\backtester.py:229: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if(closingsignals[self.positions['Coin'] == coin].shape[0] != 0): #this also happens automatically with the other warning
# C:\Users\User\Desktop\Dissertation\CryptoPredictor\CryptoPredictor\BackTest\backtester.py:235: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   requiredcoins['Amount'] = requiredcoins['Amount'] * -1
# Portfolio Stats:
# Total Return: 1414.39%
# Sharpe Ratio: 3.509 Calmar Ratio: 6.957 Sortino Ratio: 149.007 Maximum Drawdown: -29.37%
#
# BTC Portfolio:
# Total Return: 1530.2%
# Sharpe Ratio: 2.187 Calmar Ratio: 0.021 Sortino Ratio: 2.678 Maximum Drawdown: -20.1%
#
# LTC Portfolio:
# Total Return: 1385.17%
# Sharpe Ratio: 1.638 Calmar Ratio: 0.017 Sortino Ratio: 2.636 Maximum Drawdown: -31.04%
#
# ETH Portfolio:
# Total Return: 42251.41%
# Sharpe Ratio: 2.544 Calmar Ratio: 0.026 Sortino Ratio: 4.559 Maximum Drawdown: -41.33%
#
# DASH Portfolio:
# Total Return: 11118.58%
# Sharpe Ratio: 2.434 Calmar Ratio: 0.023 Sortino Ratio: 4.471 Maximum Drawdown: -34.6%
