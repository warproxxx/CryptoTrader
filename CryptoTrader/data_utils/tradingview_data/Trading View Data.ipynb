# %%
from tradingviewManger import manage
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %%
tm = manage()

# %%
tm.download()
# Out:
# https://tradingview.com/chart/XRPUSD/POmKdDW7-Trading-plan-XRPUSD-Ripple/
# 1529395055.0
# 1528435266.0
# https://tradingview.com/chart/XRPUSD/iy7gQ2f8-xrpusd-masterphi-idea/
# 1529382182.0
# 1528435266.0
# https://tradingview.com/chart/BTCUSD/mhFS34Bf-Trade-war-on-Cash-App-accepts-BTC-New-date-AUG-11/
# 1529379887.0
# 1528435266.0
# https://tradingview.com/chart/XRPUSD/vJvlJ5KD-XRP-Short-Midterm-Long/
# 1529350018.0
# 1528435266.0
# https://tradingview.com/chart/XRPUSD/LxBseSA6-XRPUSD-finally-the-spike/
# 1529340783.0
# 1528435266.0
# https://tradingview.com/chart/XRPUSD/Q7UmGBSE-Fundstrat-Recent-Research-Bitcoin-AI-ML-Signal/
# 1529337228.0
# 1528435266.0
# https://tradingview.com/chart/XRPUSD/qLyUVAHH-XRP-still-on-schedule-to-get-there/
# 1529315794.0
# 1528435266.0
# https://tradingview.com/chart/XRPUSD/dPllXBBA-Trading-plan-XRPUSD-Ripple/
# 1529308315.0
# 1528435266.0
# https://tradingview.com/chart/XRPUSD/XorS1vKj-Ripple-to-0-45/
# 1529270465.0
# 1528435266.0
# ...
