# %%
import os
import pandas as pd
from glob import glob
import numpy as np

# %%
currpath = os.getcwd()

# %%
fulldf = None

for file in glob(currpath + "/data/live/*"):
    if "debug" not in file:
        df = pd.read_csv(file, engine="python")
        
        if fulldf is None:
            fulldf=df[:0]
            
        fulldf = pd.concat([fulldf, df])

# %%
fulldf['Time'] = pd.to_datetime(fulldf['Time'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-7c1ce3bb8b26> in <module>()
# ----> 1 fulldf['Time'] = pd.to_datetime(fulldf['Time'], errors='coerce')
#
# TypeError: 'NoneType' object is not subscriptable

# %%
fulldf = fulldf.sort_values('Time').dropna(subset=['Time']).drop('Unnamed: 0', axis=1).reset_index(drop=True) #subset='time' is there because for tweets, in response to is NaN
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-f80f33ae08b9> in <module>()
# ----> 1 fulldf = fulldf.sort_values('Time').dropna(subset=['Time']).drop('Unnamed: 0', axis=1).reset_index(drop=True) #subset='time' is there because for tweets, in response to is NaN
#
# AttributeError: 'NoneType' object has no attribute 'sort_values'

# %%
fulldf.groupby('response_type').count()
# Out:
#                     ID   Tweet    Time    User   Likes  Replies  Retweets  \
# response_type
# quoted_retweet    9438    9438    9438    9438    9438     9438      9438
# reply            11196   11196   11196   11196   11196    11196     11196
# retweet         111417  111417  111417  111417  111417   111417    111417
# tweet            79157   79157   79157   79157   79157    79157     79157
#
#                 in_response_to  coinname
# response_type
# quoted_retweet            9438      9438
# reply                    11196     11196
# retweet                 111417    111417
# tweet                        0     79157

# %%
live_profile = pd.read_csv('data/profiledata/live/1530498566_1530498581.csv')

# %%
live_profile
# Out:
#     Unnamed: 0         username     created                     location  \
# 0            0           atx286  2009-11-30   Atras de ti... behind you!
# 1            1       POTUS_C137  2015-04-17                            0
# 2            2     buivietthai7  2018-06-05                            0
# 3            3      TingTong197  2018-03-22                            0
# 4            4    princebridge7  2017-10-30                            0
# 5            5   collegeappspec  2017-02-25                            0
# 6            6      4Janvisingh  2017-09-27                            0
# 7            7    CryptoMessiah  2014-07-29                            0
# 8            8  zenuxerofficial  2015-09-11  Kota Probolinggo, East Java
# 9            9        IndGiffie  2017-10-29                            0
# 10          10    DangVinhHung2  2018-07-01                            0
# 11          11   Twefmil_Crypto  2018-03-08                            0
# 12          12         Jash5200  2017-08-21                            0
# 13          13  JamesJe65927239  2015-10-09                            0
# 14          14      BBt22111995  2018-04-23                            0
# 15          15  SapphireAtlas98  2017-10-22                            0
# 16          16     maxitremblay  2010-12-23                            0
# 17          17    AlexAthlete86  2017-09-18                            0
# 18          18  NguyenX40874982  2018-06-17                            0
# 19          19  DinabandhuNay20  2017-08-16                            0
# 20          20   LadySunshineNM  2010-01-17               Albuquerque NM
# 21          21      BrandonADee  2013-01-17                            0
# 22          22        ageofbits  2018-06-08                            0
# 23          23          FoxHODL  2017-11-02                            0
# 24          24  JefferyVargas15  2018-07-02                            0
# 25          25       RealBryGuy  2010-12-12                            0
# 26          26            ZYL5_  2012-12-19                            0
# 27          27       haydentiff  2014-07-25                            0
# 28          28        lowstrife  2014-03-28                            0
#
#     has_location  is_verified  total_tweets  total_following  total_followers  \
# 0              1            0         20689              925              436
# 1              0            0           125              138               74
# 2              0            0             7               51                1
# 3              0            0          3311             6991             6697
# 4              0            0          2531             4606             2524
# 5              0            0           207              241               28
# 6              0            0           297              108               58
# 7              0            0         24568              430            55810
# 8              1            0          5705             4913             1744
# 9              0            0            67                1              269
# 10             0            0           115              139                0
# 11             0            0           231              262               56
# 12             0            0           132              259               29
# 13             0            0          3712              616              236
# 14             0            0             7                2               36
# 15             0            0          1920               49               24
# 16             0            0          2813             1210              553
# 17             0            0          7033            10195             9425
# 18             0            0            43               69                3
# 19             0            0         45742              717              289
# 20             1            1          1454             1133             7011
# 21             0            0          1666              105               61
# 22             0            0             1               60                8
# 23             0            0         10545               83              213
# 24             0            0             1                0                0
# 25             0            0          9886              579              237
# 26             0            0           926               23               14
# 27             0            1         64625            12229            68320
# 28             0            0          1840              126            13772
#
#     total_likes  has_avatar  has_background  is_protected  profile_modified
# 0          1533           1               1             0                 1
# 1           538           1               0             0                 1
# 2             5           1               1             0                 1
# 3          2351           1               1             0                 1
# 4          2485           1               1             0                 1
# 5           101           1               0             0                 1
# 6           331           1               1             0                 1
# 7         20519           1               0             0                 1
# 8          3926           1               1             0                 1
# 9            58           1               1             0                 1
# 10           47           0               1             0                 1
# 11          183           1               1             0                 1
# 12           46           1               1             0                 1
# 13         3807           1               1             0                 1
# 14            6           1               1             0                 1
# 15           56           1               0             0                 1
# 16         2041           1               0             0                 1
# 17         4795           1               1             0                 1
# 18           18           0               1             0                 1
# 19        68305           1               1             0                 1
# 20          156           1               1             0                 1
# 21          249           1               1             0                 1
# 22            0           1               1             0                 1
# 23            5           1               1             0                 1
# 24            0           0               1             0                 1
# 25         1594           1               1             0                 1
# 26         1555           1               1             0                 1
# 27        72025           1               0             0                 1
# 28         1238           1               1             0                 1

# %%
from historic_utils import historicDownloader, historicUtils
from datetime import date, datetime, timedelta, timezone
from dateutil.relativedelta import relativedelta
import logging

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %%
keywords = {'bitcoin': ['bitcoin', 'BTC'], 'dashcoin': ['dashcoin', 'DASH', 'darkcoin'], 'dogecoin': ['dogecoin', 'DOGE'], 'ethereum': ['ethereum', 'ETH'], 'litecoin': ['litecoin', 'LTC'], 'ripple': ['ripple', 'XRP'], 'monero': ['monero', 'XMR'], 'stellar': ['stellar', 'STR']}

keywordsAll = [value for key, values in keywords.items()
                       for value in values]

starting = (datetime.now() - timedelta(hours=6)).date()
ending = datetime.now().date() + timedelta(days=1)

detailsList = []

for key, values in keywords.items():
    detailsList.append({'keyword': ' OR '.join(values), 'coinname': key, 'start': starting, 'end': ending})

# %%
detailsList
# Out:
# [{'coinname': 'monero',
#   'end': datetime.date(2018, 7, 5),
#   'keyword': 'monero OR XMR',
#   'start': datetime.date(2018, 7, 4)},
#  {'coinname': 'dashcoin',
#   'end': datetime.date(2018, 7, 5),
#   'keyword': 'dashcoin OR DASH OR darkcoin',
#   'start': datetime.date(2018, 7, 4)},
#  {'coinname': 'ripple',
#   'end': datetime.date(2018, 7, 5),
#   'keyword': 'ripple OR XRP',
#   'start': datetime.date(2018, 7, 4)},
#  {'coinname': 'litecoin',
#   'end': datetime.date(2018, 7, 5),
#   'keyword': 'litecoin OR LTC',
#   'start': datetime.date(2018, 7, 4)},
#  {'coinname': 'dogecoin',
#   'end': datetime.date(2018, 7, 5),
#   'keyword': 'dogecoin OR DOGE',
#   'start': datetime.date(2018, 7, 4)},
#  {'coinname': 'stellar',
#   'end': datetime.date(2018, 7, 5),
#   'keyword': 'stellar OR STR',
#   'start': datetime.date(2018, 7, 4)},
#  {'coinname': 'bitcoin',
#   'end': datetime.date(2018, 7, 5),
#   'keyword': 'bitcoin OR BTC',
#   'start': datetime.date(2018, 7, 4)},
#  {'coinname': 'ethereum',
#   'end': datetime.date(2018, 7, 5),
#   'keyword': 'ethereum OR ETH',
#   'start': datetime.date(2018, 7, 4)}]

# %%
hu = historicUtils(detailsList)
hu.delete_files()

# %%
hd = historicDownloader(detailsList, logger=logger)

# %%
data = hd.perform_scraping(form='return')
# Out:
# INFO:root:Scraping monero Data
# INFO:root:Starting Year: 2018 Ending Year: 2018
# INFO:root:Current Starting Date:2018-07-04 Current Ending Date:2018-07-05
# INFO:root:Querying monero OR XMR since:2018-07-04 until:2018-07-05
# INFO:root:Got 32 tweets for monero%20OR%20XMR%20since%3A2018-07-04%20until%3A2018-07-05.
# INFO:root:Got 32 tweets (32 new).
# INFO:root:Scraping dashcoin Data
# INFO:root:Starting Year: 2018 Ending Year: 2018
# INFO:root:Current Starting Date:2018-07-04 Current Ending Date:2018-07-05
# INFO:root:Querying dashcoin OR DASH OR darkcoin since:2018-07-04 until:2018-07-05
# INFO:root:Got 141 tweets for dashcoin%20OR%20DASH%20OR%20darkcoin%20since%3A2018-07-04%20until%3A2018-07-05.
# INFO:root:Got 141 tweets (141 new).
# INFO:root:Scraping ripple Data
# INFO:root:Starting Year: 2018 Ending Year: 2018
# INFO:root:Current Starting Date:2018-07-04 Current Ending Date:2018-07-05
# INFO:root:Querying ripple OR XRP since:2018-07-04 until:2018-07-05
# INFO:root:Got 126 tweets for ripple%20OR%20XRP%20since%3A2018-07-04%20until%3A2018-07-05.
# INFO:root:Got 126 tweets (126 new).
# INFO:root:Scraping litecoin Data
# INFO:root:Starting Year: 2018 Ending Year: 2018
# INFO:root:Current Starting Date:2018-07-04 Current Ending Date:2018-07-05
# INFO:root:Querying litecoin OR LTC since:2018-07-04 until:2018-07-05
# INFO:root:Got 73 tweets for litecoin%20OR%20LTC%20since%3A2018-07-04%20until%3A2018-07-05.
# INFO:root:Got 73 tweets (73 new).
# INFO:root:Scraping dogecoin Data
# INFO:root:Starting Year: 2018 Ending Year: 2018
# INFO:root:Current Starting Date:2018-07-04 Current Ending Date:2018-07-05
# INFO:root:Querying dogecoin OR DOGE since:2018-07-04 until:2018-07-05
# INFO:root:Got 102 tweets for dogecoin%20OR%20DOGE%20since%3A2018-07-04%20until%3A2018-07-05.
# INFO:root:Got 102 tweets (102 new).
# INFO:root:Scraping stellar Data
# INFO:root:Starting Year: 2018 Ending Year: 2018
# INFO:root:Current Starting Date:2018-07-04 Current Ending Date:2018-07-05
# INFO:root:Querying stellar OR STR since:2018-07-04 until:2018-07-05
# INFO:root:Got 134 tweets for stellar%20OR%20STR%20since%3A2018-07-04%20until%3A2018-07-05.
# INFO:root:Got 134 tweets (134 new).
# INFO:root:Scraping bitcoin Data
# INFO:root:Starting Year: 2018 Ending Year: 2018
# INFO:root:Current Starting Date:2018-07-04 Current Ending Date:2018-07-05
# INFO:root:Querying bitcoin OR BTC since:2018-07-04 until:2018-07-05
# INFO:root:Got 280 tweets for bitcoin%20OR%20BTC%20since%3A2018-07-04%20until%3A2018-07-05.
# INFO:root:Got 280 tweets (280 new).
# INFO:root:Scraping ethereum Data
# INFO:root:Starting Year: 2018 Ending Year: 2018
# INFO:root:Current Starting Date:2018-07-04 Current Ending Date:2018-07-05
# INFO:root:Querying ethereum OR ETH since:2018-07-04 until:2018-07-05
# INFO:root:Got 146 tweets for ethereum%20OR%20ETH%20since%3A2018-07-04%20until%3A2018-07-05.
# INFO:root:Got 146 tweets (146 new).

# %%
df = data['bitcoin']['2018-07-04']

# %%
df = df.assign(f = df['Likes'].astype(int) + df['Replies'].astype(int) + df['Retweet'].astype(int)).sort_values('f', ascending=False).drop('f', axis=1).reset_index(drop=True)

# %%
#only get data that is 6 hours and shorter

# %%
df['Time'] = pd.to_datetime(df['Time'], errors='coerce')

# %%
df['Time'] = df['Time'].astype(np.int64) // 10 ** 9

# %%
three_ago = int((datetime.now() - timedelta(hours=6)).replace(tzinfo=timezone.utc).timestamp())

# %%
three_ago
# Out:
# 1530670610

# %%
df[df['Time'] > three_ago]
# Out:
#                       ID                                              Tweet  \
# 0    1014334348886204417  Ripple gets sued again for securities fraud. T...
# 4    1014332342146564096  Bank of Finland says BTC is valueless cuz it’s...
# 6    1014381216714244096  20 $NEO Giveaway! 15 Hours Left to Enter! \n\n...
# 7    1014354381850992641  Bitcoin futures killed the bitcoin rally, econ...
# 13   1014374170027687936  2011 $BTC Bubble pops $32 - $2 - 94% retrace\n...
# 14   1014374170027687936  2011 $BTC Bubble pops $32 - $2 - 94% retrace\n...
# 15   1014344753134129152  Read more about it at https://cybit.io/#recent...
# 16   1014347336565157889  $BTC UPDATE: BAD NEWS GUYS... I found 5 differ...
# 17   1014340867056754689  My feed of the veteran traders today vs the no...
# 18   1014386619003138048  Paul Krugman Trolls Ripple, Accidentally Makin...
# 22   1014365042496634880  Remember folks, bitcoin being announced “dead”...
# 23   1014357238083997701  PRICE KEEPS REPEATING THE SAME PATTERN \nFood ...
# 28   1014348925027921920  Five Nations Join Efforts to Punish Transnatio...
# 29   1014416860220043264  EU Report Advises Regulators Not to Ban or Ign...
# 30   1014365724893016064  $BTC\nany further impulse wave has been invali...
# 32   1014334802504355842    Buying this $btc dip pic.twitter.com/bOF8AbPRYO
# 33   1014363750126587905  Binance $SYS hack today: The hackers got a hol...
# 34   1014380895615275009  Extreme Bitcoin mining brings an unexpected re...
# 35   1014405572651880448  Don't know what to do with this rare feeling o...
# 37   1014358345799622657  Stop using high leverage and pick your spots c...
# 39   1014343013915594753  i'd rather start slanging crack than set up a ...
# 43   1014361397310832640  You're going to want to\n\n1. Buy $PAL\n2. RET...
# 44   1014349473617793025  Hackearon a SYSCOIN? o Hackearon a BInance? o ...
# 45   1014396400438611968  It's both frustrating and satisfying to see fo...
# 46   1014396400438611968  It's both frustrating and satisfying to see fo...
# 47   1014409248342773761  A restaurant in Nyeri Town called Betty’s Plac...
# 50   1014390290549886976  DGB will come back to the ATH of $0.14 eventua...
# 56   1014373172479774721  the whole point is to get as much bitcoin as y...
# 57   1014356902430507013  GLN offers a working product, playable games o...
# 58   1014369721507106818  Syscoin’s blockchain compromised as 1 SYS trad...
# ..                   ...                                                ...
# 114  1014411311671726080  Man asks me what I do for a living. \nMe: I am...
# 116  1014344976837300225  Seems like haters want to talk regulation late...
# 118  1014414825764425728  #bitcoin sound money or high end currencies ca...
# 119  1014344769273782272  Get a dose of Your Daily #CryptoNews: Titans o...
# 120  1014371442996101120          $BTC 240\ntest pic.twitter.com/usKRQaInXs
# 122  1014341792182030336  Liberty and freedom BTCZ! Decentralized we tru...
# 124  1014360598627438592  What other #blockchain influencers do you foll...
# 125  1014340307624685569  At first it might not seem like bitcoin is the...
# 127  1014359801789337600  A big reference sheet commission for an Instag...
# 131  1014368011598299136  If you had to choose a coin to invest in today...
# 133  1014343353394229249  This Brazilian entrepreneur just created the f...
# 134  1014355491667918848  Price of bitcoin has been going down since Jan...
# 135  1014344915390611458  Executive Mansion\nJul 3rd 2018\n\nIf you want...
# 136  1014413854191726592  “Feeling thankful and grateful to be on this j...
# 138  1014374820417433600  The #Bitcoin #Rodeo welcomes Moon, the fluffy ...
# 141  1014350555026604032  7 Best Bitcoin Wallet Apps For Android in 2018...
# 143  1014406334408724481  The world's most epic fails\n\n#AI #IoT #digit...
# 145  1014419071884935168  Lost 60 mill Volume but no Price... weird. #BT...
# 150  1014417124138340352  Where were you when the #Crypto 2018 Crash too...
# 151  1014418292361121792  We are searching for a skilled:\n\nLead Design...
# 155  1014346486803394561  Executive Mansion\nJul 3 2018\n\nImportant pri...
# 157  1014414696097636352  $NEO what kinds of news will you bring to the ...
# 159  1014413609898631168  Interested in Quantum Computing & Bitcoin? @Al...
# 162  1014361243178504193  7 Best Bitcoin Wallet Apps For Android in 2018...
# 176  1014339032740855809  SEC Seeks Comments on Another Bitcoin ETF http...
# 188  1014336883877244928  Tom Lee Bitcoin Something Big Is Coming in Dec...
# 191  1014388799277846528  Imagine $1000 on $sys because it was being mas...
# 197  1014411294647218177  $BTC\n\nSwitzerland Set To Embrace Bitcoin: Sw...
# 202  1014405043305541632  One of the Capital Technologies & Research goa...
# 252  1014420762487238656  What is WGT?\n\nBy changing items and goods in...
#
#            Time             User Likes Replies Retweet       in_response_to  \
# 0    1530671128  ArminVanBitcoin   244      18     104                    0
# 4    1530670650  intangiblecoins   141       8      40                    0
# 6    1530682303      SmokinEther    94      11      68  1014243026628038656
# 7    1530675905  FortuneMagazine    96      18      48                    0
# 13   1530680622    CryptoRanger1    90       3      26                    0
# 14   1530680622    CryptoRanger1    90       3      26                    0
# 15   1530673609        CybitCorp    64       1      46                    0
# 16   1530674225  Bleeding_Crypto    80      14      14                    0
# 17   1530672682      bitcoin_dad    84       6       6                    0
# 18   1530683591            BTCTN    52      12      27                    0
# 22   1530678446        Dmitriysz    59       4      20                    0
# 23   1530676586     CryptoTrendy    64       3      12                    0
# 28   1530674604            BTCTN    34       6      33                    0
# 29   1530690801            BTCTN    44       1      26                    0
# 30   1530678609          SwadeHD    52       8      10                    0
# 32   1530671237          MrJozza    53       6      11                    0
# 33   1530678138  TommyWorldPower    42       9      16                    0
# 34   1530682226         business    41       2      21                    0
# 35   1530688109          Sathnam    55       3       5                    0
# 37   1530676850     coin_signals    52       5       5                    0
# 39   1530673194     BitcoinDunny    38       6      15                    0
# 43   1530677577   btcfundmanager    26       5      18  1014356871321227265
# 44   1530674734    DanielMuvdiYT    31       5      12                    0
# 45   1530685923            LeoAW    31       5       8                    0
# 46   1530685923            LeoAW    31       5       8                    0
# 47   1530688986  kenyanwalstreet    23       1      20                    0
# 50   1530684466        tommyp408    25       0      17                    0
# 56   1530680385     CryptoGayGuy    28       4       3                    0
# 57   1530676506  gamelootnetwork    20       0      15                    0
# 58   1530679562       el33th4xor    23       3       9                    0
# ..          ...              ...   ...     ...     ...                  ...
# 114  1530689478  Bitcoinlife2012     8       1       3                    0
# 116  1530673662         BGIradji     7       1       4                    0
# 118  1530690316  alonsovalenciav     6       0       5                    0
# 119  1530673613      Bitboy_Hodl     7       0       4                    0
# 120  1530679972      cryptolenon     7       1       3                    0
# 122  1530672903      Icestorm18C     8       0       3                    0
# 124  1530677387  DREAM_Ecosystem     7       0       4                    0
# 125  1530672549    SoakerPatoshi     6       2       3                    0
# 127  1530677197  bitcoin_bullies     7       3       1                    0
# 131  1530679154  crypto_canadian     3       4       3                    0
# 133  1530673275    bogartscoffee     6       0       4                    0
# 134  1530676169   ElJefeDSecurIT     7       0       3                    0
# 135  1530673648   bitcoinlincoln     6       0       3                    0
# 136  1530690084     faliceplease     6       0       3                    0
# 138  1530680778  bitcoinrodeoyyc     6       0       3                    0
# 141  1530674992         anarle7s     5       0       3                    0
# 143  1530688291  kashthefuturist     5       0       3                    0
# 145  1530691328   SwoleOffCrypto     4       3       1                    0
# 150  1530690864      Kiss_Crypto     5       2       0                    0
# 151  1530691142    THEBITCOINONE     4       0       2                    0
# 155  1530674022   bitcoinlincoln     5       0       1                    0
# 157  1530690285     UpwardCrypto     4       0       2                    0
# 159  1530690026    NuggetsNewsAU     3       1       2                    0
# 162  1530677540  gorshkovahristi     4       0       2  1014361240003416064
# 176  1530672245      TokenTalkDD     3       0       1                    0
# 188  1530671733       devnullius     1       0       2                    0
# 191  1530684110    BitcoinBeluga     3       0       0                    0
# 197  1530689474  LeeCryptoTrader     2       0       0                    0
# 202  1530687983  CryptoByChemist     1       0       1                    0
# 252  1530691731  bitcoin_chicken     0       0       0                    0
#
#       response_type
# 0             reply
# 4             reply
# 6    quoted_retweet
# 7             reply
# 13            reply
# 14            reply
# 15            reply
# 16            reply
# 17            reply
# 18            reply
# 22            reply
# 23            reply
# 28            reply
# 29            reply
# 30            reply
# 32            reply
# 33            reply
# 34            reply
# 35            reply
# 37            reply
# 39            reply
# 43   quoted_retweet
# 44            reply
# 45            reply
# 46            reply
# 47            reply
# 50            reply
# 56            reply
# 57            reply
# 58            reply
# ..              ...
# 114           reply
# 116           reply
# 118           reply
# 119           reply
# 120           reply
# 122           reply
# 124           reply
# 125           reply
# 127           reply
# 131           reply
# 133           reply
# 134           reply
# 135           reply
# 136           reply
# 138           reply
# 141           reply
# 143           reply
# 145           reply
# 150           reply
# 151           reply
# 155           reply
# 157           reply
# 159           reply
# 162           reply
# 176           reply
# 188           reply
# 191           reply
# 197           reply
# 202           reply
# 252           reply
#
# [85 rows x 9 columns]
