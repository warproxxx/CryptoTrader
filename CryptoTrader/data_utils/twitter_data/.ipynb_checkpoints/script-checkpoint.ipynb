# %%
from twitterscraper import query_tweets

from dateutil.relativedelta import relativedelta
from dateutil.rrule import rrule, MONTHLY
from datetime import datetime, date, timedelta


import pandas as pd
import time

import os

import requests

from glob import glob

import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def proxy_dict(address):
    http_proxy  = "http://{}".format(address)
    https_proxy = "https://{}".format(address)
    ftp_proxy   = "ftp://{}".format(address)

    proxyDict = { 
                  "http"  : http_proxy, 
                  "https" : https_proxy, 
                  "ftp"   : ftp_proxy
                }
    
    return proxyDict

# %%
def get_proxies():
    a = open('proxies.txt')

    proxies = []

    for line in a.readlines():
        proxy = proxy_dict(line.replace('\n', ''))
        proxies.append(proxy)
        
    return proxies

# %%
def scrape(start_date, end_date, proxy, keyword="Bitcoin"):
    
    for dt in rrule(MONTHLY, dtstart=start_date, until=end_date):
        
        fname = "{}/extracted/{}.csv".format(keyword.lower(), dt.strftime('%Y-%m-%d'))
        current_directory = os.getcwd()
        final_directory = os.path.join(current_directory, fname)                                     
        
        #do if file dosen't exisst
        if not os.path.exists(final_directory):           
            df = pd.DataFrame(columns=['ID', 'Tweet', 'Time', 'User', 'Likes', 'Replies', 'Retweet', 'in_response_to'])

            begin = dt.date() - relativedelta(months=1) - relativedelta(days=1)
            end = dt.date()

            print("{} {}".format(begin, end))

            selectedDays = (end - begin).days

            list_of_tweets = query_tweets(keyword, 10000 * selectedDays, begindate=begin, enddate=end, poolsize=selectedDays, proxies=proxy)

            for tweet in list_of_tweets:
                df = df.append({'ID': tweet.id, 'Tweet': tweet.text, 'Time': tweet.timestamp, 'User': tweet.user, 'Likes': tweet.likes, 'Replies': tweet.replies, 'Retweet': tweet.retweets, 'in_response_to': tweet.reply_to_id}, ignore_index=True)

            df.to_csv(fname, index=False)

# %%
detailsList = []

today = date(datetime.now().year, datetime.now().month, datetime.now().day)

coinDetails = {}
coinDetails['name'] = 'Bitcoin'
coinDetails['start'] = date(2015, 1, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

coinDetails = {}
coinDetails['name'] = 'Dash'
coinDetails['start'] = date(2015, 5, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

coinDetails = {}
coinDetails['name'] = 'Dogecoin'
coinDetails['start'] = date(2015, 1, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

coinDetails = {}
coinDetails['name'] = 'Ethereum'
coinDetails['start'] = date(2015, 12, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

coinDetails = {}
coinDetails['name'] = 'Litecoin'
coinDetails['start'] = date(2015, 1, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

coinDetails = {}
coinDetails['name'] = 'Monero'
coinDetails['start'] = date(2015, 1, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

coinDetails = {}
coinDetails['name'] = 'Ripple'
coinDetails['start'] = date(2015, 1, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

coinDetails = {}
coinDetails['name'] = 'Stellar'
coinDetails['start'] = date(2015, 1, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

# %%
def fix_paths():
    for coinDetail in detailsList:

        current_directory = os.getcwd()
        final_directory = os.path.join(current_directory, coinDetail['name'].lower())

        if not os.path.exists(final_directory):
            os.makedirs(final_directory)

        if not os.path.exists(final_directory + "/extracted"):
            os.makedirs(final_directory + "/extracted")
            
#fix_paths()

# %%
def delete_files():
    for coinDetail in detailsList:
        current_directory = os.getcwd()
        final_directory = os.path.join(current_directory, coinDetail['name'].lower()) + "/extracted/*"
        
        for f in glob.glob(final_directory):
            print("Deleting {}".format(final_directory))
            os.remove(final_directory)
            
            
#delete_files()

# %%
proxies = get_proxies()
proxySize = len(proxies)
count = 0

for coinDetail in detailsList:
    print("Scraping {} Data".format(coinDetail['name']))
    print("Starting Year: {} Ending Year: {}".format(coinDetail['start'].year, coinDetail['end'].year))
    
    proxy = proxies[count]
    
    for d in range(coinDetail['start'].year, coinDetail['end'].year + 1):
        
        if d == 2018:
            scrape(date(d, 1, 1), coinDetail['end'], proxy=proxy, keyword=coinDetail['name'])
        else:
            if count == 0:
                scrape(coinDetail['start'], date(d, 12, 31), proxy=proxy, keyword=coinDetail['name'])
            else:
                scrape(date(d, 1, 1), date(d, 12, 31), proxy=proxy, keyword=coinDetail['name'])
            
        count +=1
        
        if (count >= proxySize):
            count = 0
# Out:
# Scraping Bitcoin Data
# Starting Year: 2015 Ending Year: 2018
# Scraping Dash Data
# Starting Year: 2015 Ending Year: 2018
# 2014-11-30 2015-01-01
# INFO:root:Querying Dash since:2014-12-03 until:2014-12-04
# INFO:root:Querying Dash since:2014-12-16 until:2014-12-17
# INFO:root:Querying Dash since:2014-12-09 until:2014-12-10
# INFO:root:Querying Dash since:2014-12-05 until:2014-12-06
# INFO:root:Querying Dash since:2014-12-06 until:2014-12-07
# INFO:root:Querying Dash since:2014-12-04 until:2014-12-05
# INFO:root:Querying Dash since:2014-12-10 until:2014-12-11
# INFO:root:Querying Dash since:2014-12-11 until:2014-12-12
# INFO:root:Querying Dash since:2014-12-17 until:2014-12-18
# INFO:root:Querying Dash since:2014-12-18 until:2014-12-19
# INFO:root:Querying Dash since:2014-12-12 until:2014-12-13
# INFO:root:Querying Dash since:2014-12-07 until:2014-12-08
# INFO:root:Querying Dash since:2014-12-14 until:2014-12-15
# INFO:root:Querying Dash since:2014-12-24 until:2014-12-25
# INFO:root:Querying Dash since:2014-12-27 until:2014-12-28
# INFO:root:Querying Dash since:2014-12-28 until:2014-12-29
# INFO:root:Querying Dash since:2014-12-30 until:2014-12-31
# INFO:root:Querying Dash since:2014-12-13 until:2014-12-14
# INFO:root:Querying Dash since:2014-12-25 until:2014-12-26
# INFO:root:Querying Dash since:2014-12-08 until:2014-12-09
# INFO:root:Querying Dash since:2014-12-19 until:2014-12-20
# INFO:root:Querying Dash since:2014-12-01 until:2014-12-02
# INFO:root:Querying Dash since:2014-12-29 until:2014-12-30
# INFO:root:Querying Dash since:2014-12-26 until:2014-12-27
# INFO:root:Querying Dash since:2014-12-22 until:2014-12-23
# INFO:root:Querying Dash since:2014-12-02 until:2014-12-03
# INFO:root:Querying Dash since:2014-12-20 until:2014-12-21
# INFO:root:Querying Dash since:2014-12-15 until:2014-12-16
# INFO:root:Querying Dash since:2014-12-23 until:2014-12-24
# INFO:root:Querying Dash since:2014-12-31 until:2015-01-01
# INFO:root:Querying Dash since:2014-11-30 until:2014-12-01
# INFO:root:Querying Dash since:2014-12-21 until:2014-12-22
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-549918384172060672-550062130956083200-...-T-0-2&q=Dash%20since%3A2014-12-30%20until%3A2014-12-31&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# INFO:root:Got 140 tweets for Dash%20since%3A2014-12-27%20until%3A2014-12-28.
# INFO:root:Got 140 tweets (140 new).
# INFO:root:Got 157 tweets for Dash%20since%3A2014-12-13%20until%3A2014-12-14.
# INFO:root:Got 297 tweets (157 new).
# INFO:root:Got 159 tweets for Dash%20since%3A2014-12-10%20until%3A2014-12-11.
# INFO:root:Got 456 tweets (159 new).
# INFO:root:Got 139 tweets for Dash%20since%3A2014-12-12%20until%3A2014-12-13.
# INFO:root:Got 595 tweets (139 new).
# INFO:root:Got 140 tweets for Dash%20since%3A2014-12-15%20until%3A2014-12-16.
# INFO:root:Got 735 tweets (140 new).
# INFO:root:Got 157 tweets for Dash%20since%3A2014-12-28%20until%3A2014-12-29.
# INFO:root:Got 892 tweets (157 new).
# INFO:root:Got 139 tweets for Dash%20since%3A2014-12-09%20until%3A2014-12-10.
# INFO:root:Got 1031 tweets (139 new).
# INFO:root:Got 159 tweets for Dash%20since%3A2014-12-25%20until%3A2014-12-26.
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-546598472724398080-546803142591913984-...-T-0-6&q=Dash%20since%3A2014-12-21%20until%3A2014-12-22&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)INFO:root:Got 1190 tweets (159 new).
#
# INFO:root:Retrying... (Attempts left: 10)
# INFO:root:Got 183 tweets for Dash%20since%3A2014-12-29%20until%3A2014-12-30.
# INFO:root:Got 1373 tweets (183 new).
# INFO:root:Got 165 tweets for Dash%20since%3A2014-12-26%20until%3A2014-12-27.
# INFO:root:Got 1538 tweets (165 new).
# INFO:root:Got 170 tweets for Dash%20since%3A2014-12-01%20until%3A2014-12-02.
# INFO:root:Got 1708 tweets (170 new).
# INFO:root:Got 151 tweets for Dash%20since%3A2014-12-11%20until%3A2014-12-12.
# INFO:root:Got 171 tweets for Dash%20since%3A2014-12-03%20until%3A2014-12-04.
# INFO:root:Got 1859 tweets (151 new).
# INFO:root:Got 167 tweets for Dash%20since%3A2014-12-17%20until%3A2014-12-18.
# INFO:root:Got 2030 tweets (171 new).
# INFO:root:Got 2197 tweets (167 new).
# INFO:root:Got 177 tweets for Dash%20since%3A2014-12-20%20until%3A2014-12-21.
# INFO:root:Got 2374 tweets (177 new).
# INFO:root:Got 160 tweets for Dash%20since%3A2014-12-23%20until%3A2014-12-24.
# INFO:root:Got 2534 tweets (160 new).
# INFO:root:Got 160 tweets for Dash%20since%3A2014-12-05%20until%3A2014-12-06.
# INFO:root:Got 2694 tweets (160 new).
# INFO:root:Got 160 tweets for Dash%20since%3A2014-12-16%20until%3A2014-12-17.
# INFO:root:Got 2854 tweets (160 new).
# INFO:root:Got 160 tweets for Dash%20since%3A2014-12-06%20until%3A2014-12-07.
# INFO:root:Got 3014 tweets (160 new).
# INFO:root:Got 167 tweets for Dash%20since%3A2014-12-04%20until%3A2014-12-05.
# INFO:root:Got 3181 tweets (167 new).
# INFO:root:Got 180 tweets for Dash%20since%3A2014-12-19%20until%3A2014-12-20.
# INFO:root:Got 3361 tweets (180 new).
# INFO:root:Got 169 tweets for Dash%20since%3A2014-12-08%20until%3A2014-12-09.
# INFO:root:Got 3530 tweets (169 new).
# INFO:root:Got 183 tweets for Dash%20since%3A2014-12-30%20until%3A2014-12-31.
# INFO:root:Got 3713 tweets (183 new).
# INFO:root:Got 179 tweets for Dash%20since%3A2014-12-18%20until%3A2014-12-19.
# INFO:root:Got 3892 tweets (179 new).
# INFO:root:Got 196 tweets for Dash%20since%3A2014-12-22%20until%3A2014-12-23.
# INFO:root:Got 4088 tweets (196 new).
# INFO:root:Got 178 tweets for Dash%20since%3A2014-12-02%20until%3A2014-12-03.
# INFO:root:Got 4266 tweets (178 new).
# INFO:root:Got 186 tweets for Dash%20since%3A2014-12-14%20until%3A2014-12-15.
# INFO:root:Got 4452 tweets (186 new).
# INFO:root:Got 200 tweets for Dash%20since%3A2014-11-30%20until%3A2014-12-01.
# INFO:root:Got 4652 tweets (200 new).
# INFO:root:Got 218 tweets for Dash%20since%3A2014-12-24%20until%3A2014-12-25.
# INFO:root:Got 4870 tweets (218 new).
# INFO:root:Got 217 tweets for Dash%20since%3A2014-12-31%20until%3A2015-01-01.
# INFO:root:Got 5087 tweets (217 new).
# INFO:root:Got 257 tweets for Dash%20since%3A2014-12-21%20until%3A2014-12-22.
# INFO:root:Got 5344 tweets (257 new).
# INFO:root:Got 277 tweets for Dash%20since%3A2014-12-07%20until%3A2014-12-08.
# INFO:root:Got 5621 tweets (277 new).
# 2014-12-31 2015-02-01
# INFO:root:Querying Dash since:2015-01-01 until:2015-01-02
# INFO:root:Querying Dash since:2015-01-04 until:2015-01-05
# INFO:root:Querying Dash since:2015-01-05 until:2015-01-06
# INFO:root:Querying Dash since:2015-01-03 until:2015-01-04
# INFO:root:Querying Dash since:2014-12-31 until:2015-01-01
# INFO:root:Querying Dash since:2015-01-12 until:2015-01-13
# INFO:root:Querying Dash since:2015-01-18 until:2015-01-19
# INFO:root:Querying Dash since:2015-01-16 until:2015-01-17
# INFO:root:Querying Dash since:2015-01-19 until:2015-01-20
# INFO:root:Querying Dash since:2015-01-21 until:2015-01-22
# INFO:root:Querying Dash since:2015-01-22 until:2015-01-23
# INFO:root:Querying Dash since:2015-01-15 until:2015-01-16
# INFO:root:Querying Dash since:2015-01-24 until:2015-01-25
# INFO:root:Querying Dash since:2015-01-17 until:2015-01-18
# INFO:root:Querying Dash since:2015-01-20 until:2015-01-21
# INFO:root:Querying Dash since:2015-01-02 until:2015-01-03
# INFO:root:Querying Dash since:2015-01-10 until:2015-01-11
# INFO:root:Querying Dash since:2015-01-26 until:2015-01-27
# INFO:root:Querying Dash since:2015-01-11 until:2015-01-12
# INFO:root:Querying Dash since:2015-01-13 until:2015-01-14
# INFO:root:Querying Dash since:2015-01-29 until:2015-01-30
# INFO:root:Querying Dash since:2015-01-27 until:2015-01-28
# INFO:root:Querying Dash since:2015-01-14 until:2015-01-15
# INFO:root:Querying Dash since:2015-01-23 until:2015-01-24
# INFO:root:Querying Dash since:2015-01-25 until:2015-01-26
# INFO:root:Querying Dash since:2015-01-30 until:2015-01-31
# INFO:root:Querying Dash since:2015-01-09 until:2015-01-10
# INFO:root:Querying Dash since:2015-01-31 until:2015-02-01
# INFO:root:Querying Dash since:2015-01-28 until:2015-01-29
# INFO:root:Querying Dash since:2015-01-06 until:2015-01-07
# INFO:root:Querying Dash since:2015-01-08 until:2015-01-09
# INFO:root:Querying Dash since:2015-01-07 until:2015-01-08
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-558293283836026880-558386733335977986-...-T-0-1&q=Dash%20since%3A2015-01-22%20until%3A2015-01-23&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# INFO:root:Got 160 tweets for Dash%20since%3A2015-01-03%20until%3A2015-01-04.
# INFO:root:Got 160 tweets (160 new).
# INFO:root:Got 140 tweets for Dash%20since%3A2015-01-04%20until%3A2015-01-05.
# INFO:root:Got 300 tweets (140 new).
# INFO:root:Got 175 tweets for Dash%20since%3A2015-01-05%20until%3A2015-01-06.
# INFO:root:Got 475 tweets (175 new).
# INFO:root:Got 161 tweets for Dash%20since%3A2015-01-09%20until%3A2015-01-10.
# INFO:root:Got 636 tweets (161 new).
# INFO:root:Got 163 tweets for Dash%20since%3A2015-01-02%20until%3A2015-01-03.
# INFO:root:Got 799 tweets (163 new).
# INFO:root:Got 157 tweets for Dash%20since%3A2015-01-27%20until%3A2015-01-28.
# INFO:root:Got 956 tweets (157 new).
# INFO:root:Got 164 tweets for Dash%20since%3A2015-01-07%20until%3A2015-01-08.
# INFO:root:Got 1120 tweets (164 new).
# INFO:root:Got 161 tweets for Dash%20since%3A2015-01-16%20until%3A2015-01-17.
# INFO:root:Got 1281 tweets (161 new).
# INFO:root:Got 177 tweets for Dash%20since%3A2015-01-24%20until%3A2015-01-25.
# INFO:root:Got 158 tweets for Dash%20since%3A2015-01-28%20until%3A2015-01-29.
# INFO:root:Got 1458 tweets (177 new).
# INFO:root:Got 1616 tweets (158 new).
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-554789953519878144-555131099861364736-...-T-0-7&q=Dash%20since%3A2015-01-13%20until%3A2015-01-14&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# INFO:root:Got 159 tweets for Dash%20since%3A2015-01-23%20until%3A2015-01-24.
# INFO:root:Got 1775 tweets (159 new).
# INFO:root:Got 161 tweets for Dash%20since%3A2015-01-17%20until%3A2015-01-18.
# INFO:root:Got 1936 tweets (161 new).
# INFO:root:Got 182 tweets for Dash%20since%3A2015-01-06%20until%3A2015-01-07.
# INFO:root:Got 171 tweets for Dash%20since%3A2015-01-14%20until%3A2015-01-15.
# INFO:root:Got 179 tweets for Dash%20since%3A2015-01-10%20until%3A2015-01-11.
# INFO:root:Got 2107 tweets (171 new).
# INFO:root:Got 2289 tweets (182 new).
# INFO:root:Got 2468 tweets (179 new).
# INFO:root:Got 181 tweets for Dash%20since%3A2015-01-13%20until%3A2015-01-14.
# INFO:root:Got 2649 tweets (181 new).
# INFO:root:Got 179 tweets for Dash%20since%3A2015-01-20%20until%3A2015-01-21.
# INFO:root:Got 2828 tweets (179 new).
# INFO:root:Got 172 tweets for Dash%20since%3A2015-01-08%20until%3A2015-01-09.
# INFO:root:Got 3000 tweets (172 new).
# INFO:root:Got 176 tweets for Dash%20since%3A2015-01-12%20until%3A2015-01-13.
# INFO:root:Got 3176 tweets (176 new).
# INFO:root:Got 179 tweets for Dash%20since%3A2015-01-15%20until%3A2015-01-16.
# INFO:root:Got 3355 tweets (179 new).
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-556964279254261760-557315532660416513-...-T-0-7&q=Dash%20since%3A2015-01-19%20until%3A2015-01-20&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-560950573768663042-561311591594217472-...-T-0-9&q=Dash%20since%3A2015-01-30%20until%3A2015-01-31&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# INFO:root:Got 180 tweets for Dash%20since%3A2015-01-21%20until%3A2015-01-22.
# INFO:root:Got 3535 tweets (180 new).
# INFO:root:Got 178 tweets for Dash%20since%3A2015-01-26%20until%3A2015-01-27.
# INFO:root:Got 3713 tweets (178 new).
# INFO:root:Got 176 tweets for Dash%20since%3A2015-01-19%20until%3A2015-01-20.
# INFO:root:Got 190 tweets for Dash%20since%3A2015-01-22%20until%3A2015-01-23.
# INFO:root:Got 3903 tweets (190 new).
# INFO:root:Got 4079 tweets (176 new).
# INFO:root:Got 186 tweets for Dash%20since%3A2015-01-29%20until%3A2015-01-30.
# INFO:root:Got 4265 tweets (186 new).
# INFO:root:Got 210 tweets for Dash%20since%3A2015-01-30%20until%3A2015-01-31.
# INFO:root:Got 4475 tweets (210 new).
# INFO:root:Got 218 tweets for Dash%20since%3A2014-12-31%20until%3A2015-01-01.
# INFO:root:Got 4693 tweets (218 new).
# INFO:root:Got 214 tweets for Dash%20since%3A2015-01-31%20until%3A2015-02-01.
# INFO:root:Got 4907 tweets (214 new).
# INFO:root:Got 235 tweets for Dash%20since%3A2015-01-25%20until%3A2015-01-26.
# INFO:root:Got 5142 tweets (235 new).
# INFO:root:Got 257 tweets for Dash%20since%3A2015-01-01%20until%3A2015-01-02.
# INFO:root:Got 5399 tweets (257 new).
# INFO:root:Got 252 tweets for Dash%20since%3A2015-01-18%20until%3A2015-01-19.
# INFO:root:Got 5651 tweets (252 new).
# INFO:root:Got 287 tweets for Dash%20since%3A2015-01-11%20until%3A2015-01-12.
# INFO:root:Got 5938 tweets (287 new).
# 2015-01-31 2015-03-01
# INFO:root:Querying Dash since:2015-02-02 until:2015-02-03
# INFO:root:Querying Dash since:2015-02-05 until:2015-02-06
# INFO:root:Querying Dash since:2015-02-11 until:2015-02-12
# INFO:root:Querying Dash since:2015-02-10 until:2015-02-11
# INFO:root:Querying Dash since:2015-02-13 until:2015-02-14
# INFO:root:Querying Dash since:2015-02-14 until:2015-02-15
# INFO:root:Querying Dash since:2015-02-16 until:2015-02-17
# INFO:root:Querying Dash since:2015-02-17 until:2015-02-18
# INFO:root:Querying Dash since:2015-02-20 until:2015-02-21
# INFO:root:Querying Dash since:2015-02-03 until:2015-02-04
# INFO:root:Querying Dash since:2015-02-01 until:2015-02-02
# INFO:root:Querying Dash since:2015-01-31 until:2015-02-01
# INFO:root:Querying Dash since:2015-02-24 until:2015-02-25
# INFO:root:Querying Dash since:2015-02-27 until:2015-02-28
# INFO:root:Querying Dash since:2015-02-08 until:2015-02-09
# INFO:root:Querying Dash since:2015-02-06 until:2015-02-07
# INFO:root:Querying Dash since:2015-02-12 until:2015-02-13
# INFO:root:Querying Dash since:2015-02-07 until:2015-02-08
# INFO:root:Querying Dash since:2015-02-19 until:2015-02-20
# INFO:root:Querying Dash since:2015-02-09 until:2015-02-10
# INFO:root:Querying Dash since:2015-02-28 until:2015-03-01
# INFO:root:Querying Dash since:2015-02-15 until:2015-02-16
# INFO:root:Querying Dash since:2015-02-26 until:2015-02-27
# INFO:root:Querying Dash since:2015-02-23 until:2015-02-24
# INFO:root:Querying Dash since:2015-02-22 until:2015-02-23
# INFO:root:Querying Dash since:2015-02-18 until:2015-02-19
# INFO:root:Querying Dash since:2015-02-21 until:2015-02-22
# INFO:root:Querying Dash since:2015-02-25 until:2015-02-26
# INFO:root:Querying Dash since:2015-02-04 until:2015-02-05
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-569504259437256705-569631338866851840-...-T-0-3&q=Dash%20since%3A2015-02-22%20until%3A2015-02-23&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-563304779645190144-563473318347812864-...-T-0-3&q=Dash%20since%3A2015-02-05%20until%3A2015-02-06&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# INFO:root:Got 137 tweets for Dash%20since%3A2015-02-28%20until%3A2015-03-01.
# INFO:root:Got 137 tweets (137 new).
# INFO:root:Got 153 tweets for Dash%20since%3A2015-02-07%20until%3A2015-02-08.
# INFO:root:Got 290 tweets (153 new).
# INFO:root:Got 159 tweets for Dash%20since%3A2015-02-12%20until%3A2015-02-13.
# INFO:root:Got 449 tweets (159 new).
# INFO:root:Got 163 tweets for Dash%20since%3A2015-02-14%20until%3A2015-02-15.
# INFO:root:Got 612 tweets (163 new).
# INFO:root:Got 157 tweets for Dash%20since%3A2015-02-19%20until%3A2015-02-20.
# INFO:root:Got 769 tweets (157 new).
# INFO:root:Got 164 tweets for Dash%20since%3A2015-02-17%20until%3A2015-02-18.
# INFO:root:Got 933 tweets (164 new).
# INFO:root:Got 164 tweets for Dash%20since%3A2015-02-13%20until%3A2015-02-14.
# INFO:root:Got 1097 tweets (164 new).
# INFO:root:Got 163 tweets for Dash%20since%3A2015-02-09%20until%3A2015-02-10.
# INFO:root:Got 1260 tweets (163 new).
# INFO:root:Got 161 tweets for Dash%20since%3A2015-02-10%20until%3A2015-02-11.
# INFO:root:Got 177 tweets for Dash%20since%3A2015-02-03%20until%3A2015-02-04.
# INFO:root:Got 1421 tweets (161 new).
# INFO:root:Got 180 tweets for Dash%20since%3A2015-02-11%20until%3A2015-02-12.
# INFO:root:Got 1598 tweets (177 new).
# INFO:root:Got 1778 tweets (180 new).
# INFO:root:Got 180 tweets for Dash%20since%3A2015-02-06%20until%3A2015-02-07.
# INFO:root:Got 1958 tweets (180 new).
# INFO:root:Got 173 tweets for Dash%20since%3A2015-02-25%20until%3A2015-02-26.
# INFO:root:Got 2131 tweets (173 new).
# INFO:root:Got 170 tweets for Dash%20since%3A2015-02-20%20until%3A2015-02-21.
# INFO:root:Got 2301 tweets (170 new).
# INFO:root:Got 200 tweets for Dash%20since%3A2015-02-23%20until%3A2015-02-24.
# INFO:root:Got 2501 tweets (200 new).
# INFO:root:Got 180 tweets for Dash%20since%3A2015-02-02%20until%3A2015-02-03.
# INFO:root:Got 2681 tweets (180 new).
# INFO:root:Got 214 tweets for Dash%20since%3A2015-01-31%20until%3A2015-02-01.
# INFO:root:Got 2895 tweets (214 new).
# INFO:root:Got 178 tweets for Dash%20since%3A2015-02-05%20until%3A2015-02-06.
# INFO:root:Got 3073 tweets (178 new).
# INFO:root:Got 189 tweets for Dash%20since%3A2015-02-24%20until%3A2015-02-25.
# INFO:root:Got 3262 tweets (189 new).
# INFO:root:Got 181 tweets for Dash%20since%3A2015-02-18%20until%3A2015-02-19.
# INFO:root:Got 3443 tweets (181 new).
# INFO:root:Got 192 tweets for Dash%20since%3A2015-02-04%20until%3A2015-02-05.
# INFO:root:Got 3635 tweets (192 new).
# INFO:root:Got 188 tweets for Dash%20since%3A2015-02-26%20until%3A2015-02-27.
# INFO:root:Got 3823 tweets (188 new).
# INFO:root:Got 216 tweets for Dash%20since%3A2015-02-15%20until%3A2015-02-16.
# INFO:root:Got 4039 tweets (216 new).
# INFO:root:Got 234 tweets for Dash%20since%3A2015-02-01%20until%3A2015-02-02.
# INFO:root:Got 4273 tweets (234 new).
# INFO:root:Got 201 tweets for Dash%20since%3A2015-02-27%20until%3A2015-02-28.
# INFO:root:Got 4474 tweets (201 new).
# INFO:root:Got 228 tweets for Dash%20since%3A2015-02-16%20until%3A2015-02-17.
# INFO:root:Got 4702 tweets (228 new).
# INFO:root:Got 245 tweets for Dash%20since%3A2015-02-21%20until%3A2015-02-22.
# INFO:root:Got 4947 tweets (245 new).
# INFO:root:Got 222 tweets for Dash%20since%3A2015-02-08%20until%3A2015-02-09.
# INFO:root:Got 5169 tweets (222 new).
# INFO:root:Got 292 tweets for Dash%20since%3A2015-02-22%20until%3A2015-02-23.
# INFO:root:Got 5461 tweets (292 new).
# 2015-02-28 2015-04-01
# INFO:root:Querying Dash since:2015-03-03 until:2015-03-04
# INFO:root:Querying Dash since:2015-02-28 until:2015-03-01
# INFO:root:Querying Dash since:2015-03-05 until:2015-03-06
# INFO:root:Querying Dash since:2015-03-07 until:2015-03-08
# INFO:root:Querying Dash since:2015-03-08 until:2015-03-09
# INFO:root:Querying Dash since:2015-03-11 until:2015-03-12
# INFO:root:Querying Dash since:2015-03-14 until:2015-03-15
# INFO:root:Querying Dash since:2015-03-15 until:2015-03-16
# INFO:root:Querying Dash since:2015-03-18 until:2015-03-19
# INFO:root:Querying Dash since:2015-03-17 until:2015-03-18
# INFO:root:Querying Dash since:2015-03-19 until:2015-03-20
# INFO:root:Querying Dash since:2015-03-06 until:2015-03-07
# INFO:root:Querying Dash since:2015-03-30 until:2015-03-31
# INFO:root:Querying Dash since:2015-03-10 until:2015-03-11
# INFO:root:Querying Dash since:2015-03-12 until:2015-03-13
# INFO:root:Querying Dash since:2015-03-16 until:2015-03-17
# INFO:root:Querying Dash since:2015-03-09 until:2015-03-10
# INFO:root:Querying Dash since:2015-03-13 until:2015-03-14
# INFO:root:Querying Dash since:2015-03-20 until:2015-03-21
# INFO:root:Querying Dash since:2015-03-21 until:2015-03-22
# INFO:root:Querying Dash since:2015-03-26 until:2015-03-27
# INFO:root:Querying Dash since:2015-03-22 until:2015-03-23
# INFO:root:Querying Dash since:2015-03-31 until:2015-04-01
# INFO:root:Querying Dash since:2015-03-29 until:2015-03-30
# INFO:root:Querying Dash since:2015-03-27 until:2015-03-28
# INFO:root:Querying Dash since:2015-03-25 until:2015-03-26
# INFO:root:Querying Dash since:2015-03-01 until:2015-03-02
# INFO:root:Querying Dash since:2015-03-28 until:2015-03-29
# INFO:root:Querying Dash since:2015-03-23 until:2015-03-24
# INFO:root:Querying Dash since:2015-03-24 until:2015-03-25
# INFO:root:Querying Dash since:2015-03-04 until:2015-03-05
# INFO:root:Querying Dash since:2015-03-02 until:2015-03-03
# INFO:root:Got 0 tweets for Dash%20since%3A2015-03-05%20until%3A2015-03-06.
# INFO:root:Got 0 tweets (0 new).
# INFO:root:Got 137 tweets for Dash%20since%3A2015-02-28%20until%3A2015-03-01.
# INFO:root:Got 137 tweets (137 new).
# INFO:root:Got 139 tweets for Dash%20since%3A2015-03-09%20until%3A2015-03-10.
# INFO:root:Got 276 tweets (139 new).
# INFO:root:Got 172 tweets for Dash%20since%3A2015-03-18%20until%3A2015-03-19.
# INFO:root:Got 448 tweets (172 new).
# INFO:root:Got 161 tweets for Dash%20since%3A2015-03-03%20until%3A2015-03-04.
# INFO:root:Got 609 tweets (161 new).
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-572909675865346048-573263089623166976-...-T-0-6&q=Dash%20since%3A2015-03-04%20until%3A2015-03-05&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# INFO:root:Got 170 tweets for Dash%20since%3A2015-03-10%20until%3A2015-03-11.
# INFO:root:Got 779 tweets (170 new).
# INFO:root:Got 156 tweets for Dash%20since%3A2015-03-11%20until%3A2015-03-12.
# INFO:root:Got 935 tweets (156 new).
# INFO:root:Got 182 tweets for Dash%20since%3A2015-03-30%20until%3A2015-03-31.
# INFO:root:Got 1117 tweets (182 new).
# INFO:root:Got 192 tweets for Dash%20since%3A2015-03-29%20until%3A2015-03-30.
# INFO:root:Got 1309 tweets (192 new).
# INFO:root:Got 158 tweets for Dash%20since%3A2015-03-20%20until%3A2015-03-21.
# INFO:root:Got 1467 tweets (158 new).
# INFO:root:Got 177 tweets for Dash%20since%3A2015-03-12%20until%3A2015-03-13.
# INFO:root:Got 1644 tweets (177 new).
# INFO:root:Got 192 tweets for Dash%20since%3A2015-03-07%20until%3A2015-03-08.
# INFO:root:Got 1836 tweets (192 new).
# INFO:root:Got 176 tweets for Dash%20since%3A2015-03-04%20until%3A2015-03-05.
# INFO:root:Got 2012 tweets (176 new).
# INFO:root:Got 180 tweets for Dash%20since%3A2015-03-19%20until%3A2015-03-20.
# INFO:root:Got 2192 tweets (180 new).
# INFO:root:Got 197 tweets for Dash%20since%3A2015-03-17%20until%3A2015-03-18.
# INFO:root:Got 2389 tweets (197 new).
# INFO:root:Got 185 tweets for Dash%20since%3A2015-03-02%20until%3A2015-03-03.
# INFO:root:Got 2574 tweets (185 new).
# INFO:root:Got 200 tweets for Dash%20since%3A2015-03-26%20until%3A2015-03-27.
# INFO:root:Got 2774 tweets (200 new).
# INFO:root:Got 186 tweets for Dash%20since%3A2015-03-28%20until%3A2015-03-29.
# INFO:root:Got 196 tweets for Dash%20since%3A2015-03-25%20until%3A2015-03-26.
# INFO:root:Got 2960 tweets (186 new).
# INFO:root:Got 3156 tweets (196 new).
# INFO:root:Got 186 tweets for Dash%20since%3A2015-03-21%20until%3A2015-03-22.
# INFO:root:Got 3342 tweets (186 new).
# INFO:root:Got 216 tweets for Dash%20since%3A2015-03-24%20until%3A2015-03-25.
# INFO:root:Got 3558 tweets (216 new).
# INFO:root:Got 209 tweets for Dash%20since%3A2015-03-06%20until%3A2015-03-07.
# INFO:root:Got 3767 tweets (209 new).
# INFO:root:Got 221 tweets for Dash%20since%3A2015-03-01%20until%3A2015-03-02.
# INFO:root:Got 3988 tweets (221 new).
# INFO:root:Got 226 tweets for Dash%20since%3A2015-03-08%20until%3A2015-03-09.
# INFO:root:Got 4214 tweets (226 new).
# INFO:root:Got 242 tweets for Dash%20since%3A2015-03-16%20until%3A2015-03-17.
# INFO:root:Got 4456 tweets (242 new).
# INFO:root:Got 236 tweets for Dash%20since%3A2015-03-23%20until%3A2015-03-24.
# INFO:root:Got 4692 tweets (236 new).
# INFO:root:Got 289 tweets for Dash%20since%3A2015-03-14%20until%3A2015-03-15.
# INFO:root:Got 4981 tweets (289 new).
# INFO:root:Got 299 tweets for Dash%20since%3A2015-03-15%20until%3A2015-03-16.
# INFO:root:Got 5280 tweets (299 new).
# INFO:root:Got 277 tweets for Dash%20since%3A2015-03-27%20until%3A2015-03-28.
# INFO:root:Got 5557 tweets (277 new).
# INFO:root:Got 300 tweets for Dash%20since%3A2015-03-13%20until%3A2015-03-14.
# INFO:root:Got 5857 tweets (300 new).
# INFO:root:Got 337 tweets for Dash%20since%3A2015-03-31%20until%3A2015-04-01.
# INFO:root:Got 6194 tweets (337 new).
# INFO:root:Got 348 tweets for Dash%20since%3A2015-03-22%20until%3A2015-03-23.
# INFO:root:Got 6542 tweets (348 new).
# 2015-03-31 2015-05-01
# INFO:root:Querying Dash since:2015-04-01 until:2015-04-02
# INFO:root:Querying Dash since:2015-04-02 until:2015-04-03
# INFO:root:Querying Dash since:2015-04-04 until:2015-04-05
# INFO:root:Querying Dash since:2015-04-07 until:2015-04-08
# INFO:root:Querying Dash since:2015-04-11 until:2015-04-12
# INFO:root:Querying Dash since:2015-04-10 until:2015-04-11
# INFO:root:Querying Dash since:2015-04-13 until:2015-04-14
# INFO:root:Querying Dash since:2015-04-16 until:2015-04-17
# INFO:root:Querying Dash since:2015-04-19 until:2015-04-20
# INFO:root:Querying Dash since:2015-04-20 until:2015-04-21
# INFO:root:Querying Dash since:2015-04-22 until:2015-04-23
# INFO:root:Querying Dash since:2015-04-29 until:2015-04-30
# INFO:root:Querying Dash since:2015-04-08 until:2015-04-09
# INFO:root:Querying Dash since:2015-04-21 until:2015-04-22
# INFO:root:Querying Dash since:2015-04-12 until:2015-04-13
# INFO:root:Querying Dash since:2015-04-06 until:2015-04-07
# INFO:root:Querying Dash since:2015-04-17 until:2015-04-18
# INFO:root:Querying Dash since:2015-04-15 until:2015-04-16
# INFO:root:Querying Dash since:2015-04-09 until:2015-04-10
# INFO:root:Querying Dash since:2015-04-23 until:2015-04-24
# INFO:root:Querying Dash since:2015-04-26 until:2015-04-27
# INFO:root:Querying Dash since:2015-04-25 until:2015-04-26
# INFO:root:Querying Dash since:2015-04-24 until:2015-04-25
# INFO:root:Querying Dash since:2015-04-18 until:2015-04-19
# INFO:root:Querying Dash since:2015-04-28 until:2015-04-29
# INFO:root:Querying Dash since:2015-04-30 until:2015-05-01
# INFO:root:Querying Dash since:2015-04-14 until:2015-04-15
# INFO:root:Querying Dash since:2015-04-27 until:2015-04-28
# INFO:root:Querying Dash since:2015-04-03 until:2015-04-04
# INFO:root:Querying Dash since:2015-04-05 until:2015-04-06
# INFO:root:Querying Dash since:2015-03-31 until:2015-04-01
# INFO:root:Got 158 tweets for Dash%20since%3A2015-04-14%20until%3A2015-04-15.
# INFO:root:Got 158 tweets (158 new).
# INFO:root:Got 154 tweets for Dash%20since%3A2015-04-17%20until%3A2015-04-18.
# INFO:root:Got 312 tweets (154 new).
# INFO:root:Got 163 tweets for Dash%20since%3A2015-04-19%20until%3A2015-04-20.
# INFO:root:Got 475 tweets (163 new).
# INFO:root:Got 179 tweets for Dash%20since%3A2015-04-07%20until%3A2015-04-08.
# INFO:root:Got 654 tweets (179 new).
# INFO:root:Got 178 tweets for Dash%20since%3A2015-04-18%20until%3A2015-04-19.
# INFO:root:Got 832 tweets (178 new).
# INFO:root:Got 178 tweets for Dash%20since%3A2015-04-15%20until%3A2015-04-16.
# INFO:root:Got 1010 tweets (178 new).
# INFO:root:Got 184 tweets for Dash%20since%3A2015-04-16%20until%3A2015-04-17.
# INFO:root:Got 1194 tweets (184 new).
# INFO:root:Got 162 tweets for Dash%20since%3A2015-04-22%20until%3A2015-04-23.
# INFO:root:Got 1356 tweets (162 new).
# INFO:root:Got 178 tweets for Dash%20since%3A2015-04-23%20until%3A2015-04-24.
# INFO:root:Got 1534 tweets (178 new).
# INFO:root:Got 191 tweets for Dash%20since%3A2015-04-20%20until%3A2015-04-21.
# INFO:root:Got 1725 tweets (191 new).
# INFO:root:Got 177 tweets for Dash%20since%3A2015-04-28%20until%3A2015-04-29.
# INFO:root:Got 192 tweets for Dash%20since%3A2015-04-13%20until%3A2015-04-14.
# INFO:root:Got 1917 tweets (192 new).
# INFO:root:Got 2094 tweets (177 new).
# INFO:root:Got 194 tweets for Dash%20since%3A2015-04-06%20until%3A2015-04-07.
# INFO:root:Got 2288 tweets (194 new).
# INFO:root:Got 183 tweets for Dash%20since%3A2015-04-21%20until%3A2015-04-22.
# INFO:root:Got 2471 tweets (183 new).
# INFO:root:Got 184 tweets for Dash%20since%3A2015-04-27%20until%3A2015-04-28.
# INFO:root:Got 2655 tweets (184 new).
# INFO:root:Got 197 tweets for Dash%20since%3A2015-04-25%20until%3A2015-04-26.
# INFO:root:Got 2852 tweets (197 new).
# INFO:root:Got 184 tweets for Dash%20since%3A2015-04-08%20until%3A2015-04-09.
# INFO:root:Got 3036 tweets (184 new).
# INFO:root:Got 194 tweets for Dash%20since%3A2015-04-11%20until%3A2015-04-12.
# INFO:root:Got 3230 tweets (194 new).
# INFO:root:Got 197 tweets for Dash%20since%3A2015-04-04%20until%3A2015-04-05.
# INFO:root:Got 3427 tweets (197 new).
# INFO:root:Got 235 tweets for Dash%20since%3A2015-04-10%20until%3A2015-04-11.
# INFO:root:Got 3662 tweets (235 new).
# INFO:root:Got 201 tweets for Dash%20since%3A2015-04-29%20until%3A2015-04-30.
# INFO:root:Got 3863 tweets (201 new).
# INFO:root:Got 198 tweets for Dash%20since%3A2015-04-24%20until%3A2015-04-25.
# INFO:root:Got 4061 tweets (198 new).
# INFO:root:Got 231 tweets for Dash%20since%3A2015-04-09%20until%3A2015-04-10.
# INFO:root:Got 4292 tweets (231 new).
# INFO:root:Got 237 tweets for Dash%20since%3A2015-04-05%20until%3A2015-04-06.
# INFO:root:Got 4529 tweets (237 new).
# INFO:root:Got 252 tweets for Dash%20since%3A2015-04-26%20until%3A2015-04-27.
# INFO:root:Got 4781 tweets (252 new).
# INFO:root:Got 249 tweets for Dash%20since%3A2015-04-30%20until%3A2015-05-01.
# INFO:root:Got 5030 tweets (249 new).
# INFO:root:Got 235 tweets for Dash%20since%3A2015-04-03%20until%3A2015-04-04.
# INFO:root:Got 5265 tweets (235 new).
# INFO:root:Got 253 tweets for Dash%20since%3A2015-04-02%20until%3A2015-04-03.
# INFO:root:Got 5518 tweets (253 new).
# INFO:root:Got 259 tweets for Dash%20since%3A2015-04-12%20until%3A2015-04-13.
# INFO:root:Got 5777 tweets (259 new).
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-583090289394348032-583409468920082434-...-T-0-14&q=Dash%20since%3A2015-04-01%20until%3A2015-04-02&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# INFO:root:Got 337 tweets for Dash%20since%3A2015-03-31%20until%3A2015-04-01.
# INFO:root:Got 6114 tweets (337 new).
# INFO:root:Got 371 tweets for Dash%20since%3A2015-04-01%20until%3A2015-04-02.
# INFO:root:Got 6485 tweets (371 new).
# 2015-04-30 2015-06-01
# INFO:root:Querying Dash since:2015-04-30 until:2015-05-01
# INFO:root:Querying Dash since:2015-05-06 until:2015-05-07
# INFO:root:Querying Dash since:2015-05-05 until:2015-05-06
# INFO:root:Querying Dash since:2015-05-04 until:2015-05-05
# INFO:root:Querying Dash since:2015-05-02 until:2015-05-03
# INFO:root:Querying Dash since:2015-05-01 until:2015-05-02
# INFO:root:Querying Dash since:2015-05-17 until:2015-05-18
# INFO:root:Querying Dash since:2015-05-14 until:2015-05-15
# INFO:root:Querying Dash since:2015-05-03 until:2015-05-04
# INFO:root:Querying Dash since:2015-05-08 until:2015-05-09
# INFO:root:Querying Dash since:2015-05-13 until:2015-05-14
# INFO:root:Querying Dash since:2015-05-16 until:2015-05-17
# INFO:root:Querying Dash since:2015-05-07 until:2015-05-08
# INFO:root:Querying Dash since:2015-05-19 until:2015-05-20
# INFO:root:Querying Dash since:2015-05-20 until:2015-05-21
# INFO:root:Querying Dash since:2015-05-22 until:2015-05-23
# INFO:root:Querying Dash since:2015-05-31 until:2015-06-01
# INFO:root:Querying Dash since:2015-05-25 until:2015-05-26
# INFO:root:Querying Dash since:2015-05-30 until:2015-05-31
# INFO:root:Querying Dash since:2015-05-23 until:2015-05-24
# INFO:root:Querying Dash since:2015-05-26 until:2015-05-27
# INFO:root:Querying Dash since:2015-05-27 until:2015-05-28
# INFO:root:Querying Dash since:2015-05-15 until:2015-05-16
# INFO:root:Querying Dash since:2015-05-09 until:2015-05-10
# INFO:root:Querying Dash since:2015-05-10 until:2015-05-11
# INFO:root:Querying Dash since:2015-05-29 until:2015-05-30
# INFO:root:Querying Dash since:2015-05-28 until:2015-05-29
# INFO:root:Querying Dash since:2015-05-11 until:2015-05-12
# INFO:root:Querying Dash since:2015-05-21 until:2015-05-22
# INFO:root:Querying Dash since:2015-05-12 until:2015-05-13
# INFO:root:Querying Dash since:2015-05-18 until:2015-05-19
# INFO:root:Querying Dash since:2015-05-24 until:2015-05-25
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-599990025862844416-600076158772776960-...-T-0-2&q=Dash%20since%3A2015-05-17%20until%3A2015-05-18&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-596267413987024896-596455116279926784-...-T-0-4&q=Dash%20since%3A2015-05-07%20until%3A2015-05-08&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-600819146520010753-601145187168100353-...-T-0-5&q=Dash%20since%3A2015-05-20%20until%3A2015-05-21&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# INFO:root:Got 163 tweets for Dash%20since%3A2015-05-25%20until%3A2015-05-26.
# INFO:root:Got 163 tweets (163 new).
# INFO:root:Got 160 tweets for Dash%20since%3A2015-05-05%20until%3A2015-05-06.
# INFO:root:Got 323 tweets (160 new).
# INFO:root:Got 164 tweets for Dash%20since%3A2015-05-16%20until%3A2015-05-17.
# INFO:root:Got 487 tweets (164 new).
# INFO:root:Got 179 tweets for Dash%20since%3A2015-05-22%20until%3A2015-05-23.
# INFO:root:Got 666 tweets (179 new).
# INFO:root:Got 177 tweets for Dash%20since%3A2015-05-19%20until%3A2015-05-20.
# INFO:root:Got 843 tweets (177 new).
# INFO:root:Got 179 tweets for Dash%20since%3A2015-05-08%20until%3A2015-05-09.
# INFO:root:Got 1022 tweets (179 new).
# INFO:root:Got 164 tweets for Dash%20since%3A2015-05-27%20until%3A2015-05-28.
# INFO:root:Got 1186 tweets (164 new).
# INFO:root:Got 180 tweets for Dash%20since%3A2015-05-30%20until%3A2015-05-31.
# INFO:root:Got 1366 tweets (180 new).
# INFO:root:Got 164 tweets for Dash%20since%3A2015-05-23%20until%3A2015-05-24.
# INFO:root:Got 1530 tweets (164 new).
# INFO:root:Got 163 tweets for Dash%20since%3A2015-05-20%20until%3A2015-05-21.
# INFO:root:Got 1693 tweets (163 new).
# INFO:root:Got 193 tweets for Dash%20since%3A2015-05-11%20until%3A2015-05-12.
# INFO:root:Got 1886 tweets (193 new).
# INFO:root:Got 178 tweets for Dash%20since%3A2015-05-13%20until%3A2015-05-14.
# INFO:root:Got 2064 tweets (178 new).
# INFO:root:Got 180 tweets for Dash%20since%3A2015-05-21%20until%3A2015-05-22.
# INFO:root:Got 2244 tweets (180 new).
# INFO:root:Got 186 tweets for Dash%20since%3A2015-05-09%20until%3A2015-05-10.
# INFO:root:Got 2430 tweets (186 new).
# INFO:root:Got 194 tweets for Dash%20since%3A2015-05-07%20until%3A2015-05-08.
# INFO:root:Got 2624 tweets (194 new).
# INFO:root:Got 185 tweets for Dash%20since%3A2015-05-06%20until%3A2015-05-07.
# INFO:root:Got 2809 tweets (185 new).
# INFO:root:Got 198 tweets for Dash%20since%3A2015-05-15%20until%3A2015-05-16.
# INFO:root:Got 3007 tweets (198 new).
# INFO:root:Got 199 tweets for Dash%20since%3A2015-05-14%20until%3A2015-05-15.
# INFO:root:Got 3206 tweets (199 new).
# INFO:root:Got 186 tweets for Dash%20since%3A2015-05-26%20until%3A2015-05-27.
# INFO:root:Got 3392 tweets (186 new).
# INFO:root:Got 180 tweets for Dash%20since%3A2015-05-28%20until%3A2015-05-29.
# INFO:root:Got 3572 tweets (180 new).
# INFO:root:Got 183 tweets for Dash%20since%3A2015-05-29%20until%3A2015-05-30.
# INFO:root:Got 3755 tweets (183 new).
# INFO:root:Got 202 tweets for Dash%20since%3A2015-05-02%20until%3A2015-05-03.
# INFO:root:Got 3957 tweets (202 new).
# INFO:root:Got 192 tweets for Dash%20since%3A2015-05-01%20until%3A2015-05-02.
# INFO:root:Got 4149 tweets (192 new).
# INFO:root:Got 183 tweets for Dash%20since%3A2015-05-18%20until%3A2015-05-19.
# INFO:root:Got 4332 tweets (183 new).
# INFO:root:Got 192 tweets for Dash%20since%3A2015-05-03%20until%3A2015-05-04.
# INFO:root:Got 4524 tweets (192 new).
# INFO:root:Got 193 tweets for Dash%20since%3A2015-05-12%20until%3A2015-05-13.
# INFO:root:Got 4717 tweets (193 new).
# INFO:root:Got 200 tweets for Dash%20since%3A2015-05-04%20until%3A2015-05-05.
# INFO:root:Got 4917 tweets (200 new).
# INFO:root:Got 239 tweets for Dash%20since%3A2015-05-31%20until%3A2015-06-01.
# INFO:root:Got 5156 tweets (239 new).
# INFO:root:Got 249 tweets for Dash%20since%3A2015-04-30%20until%3A2015-05-01.
# INFO:root:Got 5405 tweets (249 new).
# INFO:root:Got 264 tweets for Dash%20since%3A2015-05-10%20until%3A2015-05-11.
# INFO:root:Got 5669 tweets (264 new).
# INFO:root:Got 255 tweets for Dash%20since%3A2015-05-24%20until%3A2015-05-25.
# INFO:root:Got 5924 tweets (255 new).
# INFO:root:Got 257 tweets for Dash%20since%3A2015-05-17%20until%3A2015-05-18.
# INFO:root:Got 6181 tweets (257 new).
# 2015-05-31 2015-07-01
# INFO:root:Querying Dash since:2015-05-31 until:2015-06-01
# INFO:root:Querying Dash since:2015-06-04 until:2015-06-05
# INFO:root:Querying Dash since:2015-06-03 until:2015-06-04
# INFO:root:Querying Dash since:2015-06-05 until:2015-06-06
# INFO:root:Querying Dash since:2015-06-08 until:2015-06-09
# INFO:root:Querying Dash since:2015-06-10 until:2015-06-11
# INFO:root:Querying Dash since:2015-06-13 until:2015-06-14
# INFO:root:Querying Dash since:2015-06-14 until:2015-06-15
# INFO:root:Querying Dash since:2015-06-17 until:2015-06-18
# INFO:root:Querying Dash since:2015-06-15 until:2015-06-16
# INFO:root:Querying Dash since:2015-06-19 until:2015-06-20
# INFO:root:Querying Dash since:2015-06-20 until:2015-06-21
# INFO:root:Querying Dash since:2015-06-22 until:2015-06-23
# INFO:root:Querying Dash since:2015-06-23 until:2015-06-24
# INFO:root:Querying Dash since:2015-06-27 until:2015-06-28
# INFO:root:Querying Dash since:2015-06-28 until:2015-06-29
# INFO:root:Querying Dash since:2015-06-25 until:2015-06-26
# INFO:root:Querying Dash since:2015-06-07 until:2015-06-08
# INFO:root:Querying Dash since:2015-06-29 until:2015-06-30
# INFO:root:Querying Dash since:2015-06-16 until:2015-06-17
# INFO:root:Querying Dash since:2015-06-12 until:2015-06-13
# INFO:root:Querying Dash since:2015-06-24 until:2015-06-25
# INFO:root:Querying Dash since:2015-06-18 until:2015-06-19
# INFO:root:Querying Dash since:2015-06-02 until:2015-06-03
# INFO:root:Querying Dash since:2015-06-11 until:2015-06-12
# INFO:root:Querying Dash since:2015-06-06 until:2015-06-07
# INFO:root:Querying Dash since:2015-06-21 until:2015-06-22
# INFO:root:Querying Dash since:2015-06-09 until:2015-06-10
# INFO:root:Querying Dash since:2015-06-01 until:2015-06-02
# INFO:root:Querying Dash since:2015-06-30 until:2015-07-01
# ...
# INFO:root:Querying Stellar since:2018-04-02 until:2018-04-03
# INFO:root:Querying Stellar since:2018-04-06 until:2018-04-07
# INFO:root:Querying Stellar since:2018-04-13 until:2018-04-14
# INFO:root:Querying Stellar since:2018-04-14 until:2018-04-15
# INFO:root:Querying Stellar since:2018-04-09 until:2018-04-10
# INFO:root:Querying Stellar since:2018-04-15 until:2018-04-16
# INFO:root:Querying Stellar since:2018-04-20 until:2018-04-21
# INFO:root:Querying Stellar since:2018-04-17 until:2018-04-18
# INFO:root:Querying Stellar since:2018-04-18 until:2018-04-19
# INFO:root:Querying Stellar since:2018-04-25 until:2018-04-26
# INFO:root:Querying Stellar since:2018-04-03 until:2018-04-04
# INFO:root:Querying Stellar since:2018-04-19 until:2018-04-20
# INFO:root:Querying Stellar since:2018-04-21 until:2018-04-22
# INFO:root:Querying Stellar since:2018-04-29 until:2018-04-30
# INFO:root:Querying Stellar since:2018-04-28 until:2018-04-29
# INFO:root:Querying Stellar since:2018-04-04 until:2018-04-05
# INFO:root:Querying Stellar since:2018-04-27 until:2018-04-28
# INFO:root:Querying Stellar since:2018-04-24 until:2018-04-25
# INFO:root:Querying Stellar since:2018-04-23 until:2018-04-24
# INFO:root:Querying Stellar since:2018-04-12 until:2018-04-13
# INFO:root:Querying Stellar since:2018-04-22 until:2018-04-23
# INFO:root:Querying Stellar since:2018-04-30 until:2018-05-01
# INFO:root:Querying Stellar since:2018-04-16 until:2018-04-17
# INFO:root:Querying Stellar since:2018-04-26 until:2018-04-27
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-981283528393592832-981229858343841793&q=Stellar%20since%3A2018-04-03%20until%3A2018-04-04&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-982576450669891584-982701798627659776-...-T-0-0&q=Stellar%20since%3A2018-04-07%20until%3A2018-04-08&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-987543432942964736-987825706511060992-...-T-0-1&q=Stellar%20since%3A2018-04-21%20until%3A2018-04-22&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# INFO:root:Got 81 tweets for Stellar%20since%3A2018-04-08%20until%3A2018-04-09.
# INFO:root:Got 81 tweets (81 new).
# INFO:root:Got 89 tweets for Stellar%20since%3A2018-04-14%20until%3A2018-04-15.
# INFO:root:Got 170 tweets (89 new).
# INFO:root:Got 100 tweets for Stellar%20since%3A2018-04-01%20until%3A2018-04-02.
# INFO:root:Got 270 tweets (100 new).
# INFO:root:Got 96 tweets for Stellar%20since%3A2018-04-25%20until%3A2018-04-26.
# INFO:root:Got 366 tweets (96 new).
# INFO:root:Got 101 tweets for Stellar%20since%3A2018-04-21%20until%3A2018-04-22.
# INFO:root:Got 467 tweets (101 new).
# INFO:root:Got 100 tweets for Stellar%20since%3A2018-04-11%20until%3A2018-04-12.
# INFO:root:Got 567 tweets (100 new).
# INFO:root:Got 99 tweets for Stellar%20since%3A2018-04-15%20until%3A2018-04-16.
# INFO:root:Got 666 tweets (99 new).
# INFO:root:Got 87 tweets for Stellar%20since%3A2018-04-05%20until%3A2018-04-06.
# INFO:root:Got 753 tweets (87 new).
# INFO:root:Got 98 tweets for Stellar%20since%3A2018-04-06%20until%3A2018-04-07.
# INFO:root:Got 851 tweets (98 new).
# INFO:root:Got 91 tweets for Stellar%20since%3A2018-04-28%20until%3A2018-04-29.
# INFO:root:Got 90 tweets for Stellar%20since%3A2018-04-07%20until%3A2018-04-08.
# INFO:root:Got 942 tweets (91 new).
# INFO:root:Got 1032 tweets (90 new).
# INFO:root:Got 100 tweets for Stellar%20since%3A2018-04-22%20until%3A2018-04-23.
# INFO:root:Got 1132 tweets (100 new).
# INFO:root:Got 100 tweets for Stellar%20since%3A2018-04-16%20until%3A2018-04-17.
# INFO:root:Got 1232 tweets (100 new).
# INFO:root:Got 114 tweets for Stellar%20since%3A2018-04-02%20until%3A2018-04-03.
# INFO:root:Got 1346 tweets (114 new).
# INFO:root:Got 98 tweets for Stellar%20since%3A2018-04-29%20until%3A2018-04-30.
# INFO:root:Got 1444 tweets (98 new).
# INFO:root:Got 97 tweets for Stellar%20since%3A2018-04-17%20until%3A2018-04-18.
# INFO:root:Got 1541 tweets (97 new).
# INFO:root:Got 98 tweets for Stellar%20since%3A2018-04-23%20until%3A2018-04-24.
# INFO:root:Got 1639 tweets (98 new).
# INFO:root:Got 105 tweets for Stellar%20since%3A2018-04-19%20until%3A2018-04-20.
# INFO:root:Got 1744 tweets (105 new).
# INFO:root:Got 117 tweets for Stellar%20since%3A2018-04-27%20until%3A2018-04-28.
# INFO:root:Got 97 tweets for Stellar%20since%3A2018-04-24%20until%3A2018-04-25.
# INFO:root:Got 1841 tweets (97 new).
# INFO:root:Got 1958 tweets (117 new).
# INFO:root:Got 99 tweets for Stellar%20since%3A2018-04-18%20until%3A2018-04-19.
# INFO:root:Got 2057 tweets (99 new).
# INFO:root:Got 104 tweets for Stellar%20since%3A2018-03-31%20until%3A2018-04-01.
# INFO:root:Got 2161 tweets (104 new).
# INFO:root:Got 101 tweets for Stellar%20since%3A2018-04-04%20until%3A2018-04-05.
# INFO:root:Got 2262 tweets (101 new).
# INFO:root:Got 102 tweets for Stellar%20since%3A2018-04-20%20until%3A2018-04-21.
# INFO:root:Got 2364 tweets (102 new).
# INFO:root:Got 100 tweets for Stellar%20since%3A2018-04-30%20until%3A2018-05-01.
# INFO:root:Got 101 tweets for Stellar%20since%3A2018-04-12%20until%3A2018-04-13.
# INFO:root:Got 2464 tweets (100 new).
# INFO:root:Got 2565 tweets (101 new).
# INFO:root:Got 105 tweets for Stellar%20since%3A2018-04-13%20until%3A2018-04-14.
# INFO:root:Got 2670 tweets (105 new).
# INFO:root:Got 102 tweets for Stellar%20since%3A2018-04-10%20until%3A2018-04-11.
# INFO:root:Got 2772 tweets (102 new).
# INFO:root:Got 113 tweets for Stellar%20since%3A2018-04-09%20until%3A2018-04-10.
# INFO:root:Got 2885 tweets (113 new).
# INFO:root:Got 116 tweets for Stellar%20since%3A2018-04-26%20until%3A2018-04-27.
# INFO:root:Got 3001 tweets (116 new).
# INFO:root:Got 117 tweets for Stellar%20since%3A2018-04-03%20until%3A2018-04-04.
# INFO:root:Got 3118 tweets (117 new).
# 2018-04-30 2018-06-01
# INFO:root:Querying Stellar since:2018-05-02 until:2018-05-03
# INFO:root:Querying Stellar since:2018-05-01 until:2018-05-02
# INFO:root:Querying Stellar since:2018-05-05 until:2018-05-06
# INFO:root:Querying Stellar since:2018-05-04 until:2018-05-05
# INFO:root:Querying Stellar since:2018-05-08 until:2018-05-09
# INFO:root:Querying Stellar since:2018-04-30 until:2018-05-01
# INFO:root:Querying Stellar since:2018-05-17 until:2018-05-18
# INFO:root:Querying Stellar since:2018-05-20 until:2018-05-21
# INFO:root:Querying Stellar since:2018-05-07 until:2018-05-08
# INFO:root:Querying Stellar since:2018-05-10 until:2018-05-11
# INFO:root:Querying Stellar since:2018-05-06 until:2018-05-07
# INFO:root:Querying Stellar since:2018-05-15 until:2018-05-16
# INFO:root:Querying Stellar since:2018-05-03 until:2018-05-04
# INFO:root:Querying Stellar since:2018-05-09 until:2018-05-10
# INFO:root:Querying Stellar since:2018-05-21 until:2018-05-22
# INFO:root:Querying Stellar since:2018-05-30 until:2018-05-31
# INFO:root:Querying Stellar since:2018-05-27 until:2018-05-28
# INFO:root:Querying Stellar since:2018-05-13 until:2018-05-14
# INFO:root:Querying Stellar since:2018-05-23 until:2018-05-24
# INFO:root:Querying Stellar since:2018-05-14 until:2018-05-15
# INFO:root:Querying Stellar since:2018-05-25 until:2018-05-26
# INFO:root:Querying Stellar since:2018-05-26 until:2018-05-27
# INFO:root:Querying Stellar since:2018-05-19 until:2018-05-20
# INFO:root:Querying Stellar since:2018-05-29 until:2018-05-30
# INFO:root:Querying Stellar since:2018-05-18 until:2018-05-19
# INFO:root:Querying Stellar since:2018-05-24 until:2018-05-25
# INFO:root:Querying Stellar since:2018-05-28 until:2018-05-29
# INFO:root:Querying Stellar since:2018-05-12 until:2018-05-13
# INFO:root:Querying Stellar since:2018-05-16 until:2018-05-17
# INFO:root:Querying Stellar since:2018-05-22 until:2018-05-23
# INFO:root:Querying Stellar since:2018-05-31 until:2018-06-01
# INFO:root:Querying Stellar since:2018-05-11 until:2018-05-12
# INFO:root:Got 0 tweets for Stellar%20since%3A2018-05-08%20until%3A2018-05-09.
# INFO:root:Got 0 tweets (0 new).
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-994345075005165568-994301040446070784&q=Stellar%20since%3A2018-05-09%20until%3A2018-05-10&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# ERROR:root:Failed to parse JSON "Expecting value: line 1 column 1 (char 0)" while requesting "https://twitter.com/i/search/timeline?vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-991736567264894976-991825789334077440-...-T-0-0&q=Stellar%20since%3A2018-05-02%20until%3A2018-05-03&l=".
# Traceback (most recent call last):
#   File "/home/shresthanikesh23/jupyter/CryptoTraderRemote/CryptoTrader/data_utils/twitter_data/twitterscraper/query.py", line 57, in query_single_page
#     json_resp = json.loads(response.text)
#   File "/usr/lib/python3.5/json/__init__.py", line 319, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.5/json/decoder.py", line 339, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.5/json/decoder.py", line 357, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
# INFO:root:Retrying... (Attempts left: 10)
# INFO:root:Got 54 tweets for Stellar%20since%3A2018-05-31%20until%3A2018-06-01.
# INFO:root:Got 54 tweets (54 new).
# INFO:root:Got 82 tweets for Stellar%20since%3A2018-05-27%20until%3A2018-05-28.
# INFO:root:Got 136 tweets (82 new).
# INFO:root:Got 81 tweets for Stellar%20since%3A2018-05-28%20until%3A2018-05-29.
# INFO:root:Got 217 tweets (81 new).
# INFO:root:Got 79 tweets for Stellar%20since%3A2018-05-13%20until%3A2018-05-14.
# INFO:root:Got 296 tweets (79 new).
# INFO:root:Got 100 tweets for Stellar%20since%3A2018-05-07%20until%3A2018-05-08.
# INFO:root:Got 396 tweets (100 new).
# INFO:root:Got 97 tweets for Stellar%20since%3A2018-05-20%20until%3A2018-05-21.
# INFO:root:Got 84 tweets for Stellar%20since%3A2018-05-04%20until%3A2018-05-05.
# INFO:root:Got 480 tweets (84 new).
# INFO:root:Got 577 tweets (97 new).
# INFO:root:Got 96 tweets for Stellar%20since%3A2018-05-19%20until%3A2018-05-20.
# INFO:root:Got 673 tweets (96 new).
# INFO:root:Got 100 tweets for Stellar%20since%3A2018-05-11%20until%3A2018-05-12.
# INFO:root:Got 773 tweets (100 new).
# INFO:root:Got 91 tweets for Stellar%20since%3A2018-05-12%20until%3A2018-05-13.
# INFO:root:Got 864 tweets (91 new).
# INFO:root:Got 106 tweets for Stellar%20since%3A2018-05-05%20until%3A2018-05-06.
# INFO:root:Got 970 tweets (106 new).
# INFO:root:Got 101 tweets for Stellar%20since%3A2018-05-29%20until%3A2018-05-30.
# INFO:root:Got 1071 tweets (101 new).
# INFO:root:Got 112 tweets for Stellar%20since%3A2018-05-17%20until%3A2018-05-18.
# INFO:root:Got 1183 tweets (112 new).
# INFO:root:Got 104 tweets for Stellar%20since%3A2018-05-26%20until%3A2018-05-27.
# INFO:root:Got 1287 tweets (104 new).
# INFO:root:Got 112 tweets for Stellar%20since%3A2018-05-10%20until%3A2018-05-11.
# INFO:root:Got 1399 tweets (112 new).
# INFO:root:Got 111 tweets for Stellar%20since%3A2018-05-25%20until%3A2018-05-26.
# INFO:root:Got 1510 tweets (111 new).
# INFO:root:Got 99 tweets for Stellar%20since%3A2018-05-01%20until%3A2018-05-02.
# INFO:root:Got 100 tweets for Stellar%20since%3A2018-04-30%20until%3A2018-05-01.
# INFO:root:Got 1609 tweets (99 new).
# INFO:root:Got 1709 tweets (100 new).
# INFO:root:Got 101 tweets for Stellar%20since%3A2018-05-14%20until%3A2018-05-15.
# INFO:root:Got 1810 tweets (101 new).
# INFO:root:Got 108 tweets for Stellar%20since%3A2018-05-21%20until%3A2018-05-22.
# INFO:root:Got 1918 tweets (108 new).
# INFO:root:Got 107 tweets for Stellar%20since%3A2018-05-03%20until%3A2018-05-04.
# INFO:root:Got 2025 tweets (107 new).
# INFO:root:Got 108 tweets for Stellar%20since%3A2018-05-06%20until%3A2018-05-07.
# INFO:root:Got 2133 tweets (108 new).
# INFO:root:Got 112 tweets for Stellar%20since%3A2018-05-22%20until%3A2018-05-23.
# INFO:root:Got 2245 tweets (112 new).
# INFO:root:Got 111 tweets for Stellar%20since%3A2018-05-09%20until%3A2018-05-10.
# INFO:root:Got 2356 tweets (111 new).
# INFO:root:Got 117 tweets for Stellar%20since%3A2018-05-24%20until%3A2018-05-25.
# INFO:root:Got 2473 tweets (117 new).
# INFO:root:Got 115 tweets for Stellar%20since%3A2018-05-30%20until%3A2018-05-31.
# INFO:root:Got 2588 tweets (115 new).
# INFO:root:Got 119 tweets for Stellar%20since%3A2018-05-15%20until%3A2018-05-16.
# INFO:root:Got 2707 tweets (119 new).
# INFO:root:Got 115 tweets for Stellar%20since%3A2018-05-02%20until%3A2018-05-03.
# INFO:root:Got 2822 tweets (115 new).
# INFO:root:Got 118 tweets for Stellar%20since%3A2018-05-23%20until%3A2018-05-24.
# INFO:root:Got 2940 tweets (118 new).
# INFO:root:Got 121 tweets for Stellar%20since%3A2018-05-16%20until%3A2018-05-17.
# INFO:root:Got 3061 tweets (121 new).
# INFO:root:Got 123 tweets for Stellar%20since%3A2018-05-18%20until%3A2018-05-19.
# INFO:root:Got 3184 tweets (123 new).

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
def merged_data():
    dirs = glob("{}/*/".format(os.getcwd()))
    
    for directory in dirs:
        fullPath = directory + "extracted"
        
        if (os.path.exists(fullPath)):
            coinName = fullPath.split("/")[-2]
            
            print(coinName)
            
            fullDf = pd.DataFrame(columns=['ID', 'Tweet', 'Time', 'User', 'Likes', 'Replies', 'Retweet'])
            
            writeFile = fullPath + "/" + "combined.csv"
            
            if (os.path.isfile(writeFile)):
                os.remove(writeFile)
            
            for file in os.listdir(fullPath):
                csv = fullPath + "/" + file
                
                if (".csv" in csv):
                    df = pd.read_csv(csv, engine='python')
                    fullDf = pd.concat([fullDf, df[['ID', 'Tweet', 'Time', 'User', 'Likes', 'Replies', 'Retweet']]])

            fullDf = fullDf.reset_index(drop=True)
            fullDf = fullDf.replace(np.inf, np.nan)
            fullDf = fullDf.fillna(method='ffill')

            fullDf['Time'] = pd.to_datetime(fullDf['Time'], errors='coerce')
            fullDf = fullDf.dropna(subset=['Time'])
            fullDf = fullDf.sort_values(by='Time')
            
            fullDf.to_csv(writeFile, index=False)

# %%
data = merged_data()
# Out:
# ripple
# dogecoin
# monero
# stellar
# litecoin
# ethereum
# dash
# bitcoin

# %%
df = pd.read_csv('bitcoin/extracted/combined.csv')
df['Time'] = pd.to_datetime(df['Time'])

# %%
# df.set_index('Time', inplace=True)

# %%
new = pd.DataFrame(columns=['Time', 'Frequency'])

new['Time'] = df['Time']
new['Frequency'] = 1

# %%
new.set_index('Time', inplace = True)

# %%
per_half = new['Frequency'].resample('1H').sum().fillna(0)

# %%
per_half.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-cbb35b6e351b> in <module>()
# ----> 1 per_half.plot()
#
# NameError: name 'per_half' is not defined
