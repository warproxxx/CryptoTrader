# %%
from twitterscraper import query_tweets
from dateutil.relativedelta import relativedelta

from datetime import datetime, date, timedelta

import pandas as pd
import time

import os

import requests

import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def scrape(start_date, end_date, keyword="Bitcoin"):
    
    for dt in rrule(MONTHLY, dtstart=start_date, until=end_date):
        df = pd.DataFrame(columns=['ID', 'Tweet', 'Time', 'User', 'Likes', 'Replies', 'Retweet'])
        
        begin = dt.date() - relativedelta(months=1) - relativedelta(days=1)
        end = dt.date()
        
        print("{} {}".format(begin, end))
        
        selectedDays = (end - begin).days
        
        list_of_tweets = query_tweets("Bitcoin", 1000 * selectedDays, begindate=begin, enddate=end, poolsize=selectedDays)

        for tweet in list_of_tweets:
            df = df.append({'ID': tweet.id, 'Tweet': tweet.text, 'Time': tweet.timestamp, 'User': tweet.user, 'Likes': tweet.likes, 'Replies': tweet.replies, 'Retweet': tweet.retweets}, ignore_index=True)

        df.to_csv("{}/extracted/{}.csv".format(keyword.lower(), dt.strftime('%Y-%m-%d'), index=False))

# %%
detailsList = []

today = date(datetime.now().year, datetime.now().month, datetime.now().day)

coinDetails = {}
coinDetails['name'] = 'Bitcoin'
coinDetails['start'] = date(2015, 1, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

coinDetails = {}
coinDetails['name'] = 'Dash'
coinDetails['start'] = date(2015, 5, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

coinDetails = {}
coinDetails['name'] = 'Dogecoin'
coinDetails['start'] = date(2015, 1, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

coinDetails = {}
coinDetails['name'] = 'Ethereum'
coinDetails['start'] = date(2015, 12, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

coinDetails = {}
coinDetails['name'] = 'Litecoin'
coinDetails['start'] = date(2015, 1, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

coinDetails = {}
coinDetails['name'] = 'Monero'
coinDetails['start'] = date(2015, 1, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

coinDetails = {}
coinDetails['name'] = 'Ripple'
coinDetails['start'] = date(2015, 1, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

coinDetails = {}
coinDetails['name'] = 'Stellar'
coinDetails['start'] = date(2015, 1, 1)
coinDetails['end'] = today
detailsList.append(coinDetails)

# %%
for coinDetail in detailsList:
    
    current_directory = os.getcwd()
    final_directory = os.path.join(current_directory, coinDetail['name'].lower())

    if not os.path.exists(final_directory):
        os.makedirs(final_directory)
    
    if not os.path.exists(final_directory + "/extracted"):
        os.makedirs(final_directory + "/extracted")

# %%
for coinDetail in detailsList:
    print("Scraping {} Data".format(coinDetail['name']))
    print("Starting Year: {} Ending Year: {}".format(coinDetail['start'].year, coinDetail['end'].year))
    
    count = 0
    
    for d in range(coinDetail['start'].year, coinDetail['end'].year + 1):
        if d == 2018:
            scrape(date(d, 1, 1), coinDetail['end'], keyword=coinDetail['name'])
        else:
            if count == 0:
                scrape(coinDetail['start'], date(d, 12, 31), keyword=coinDetail['name'])
            else:
                scrape(date(d, 1, 1), date(d, 12, 31), keyword=coinDetail['name'])
            
        count +=1
# Out:
# Scraping Bitcoin Data
# Starting Year: 2015 Ending Year: 2018
# 2014-11-30 2015-01-01
# 2014-12-31 2015-02-01
# 2015-01-31 2015-03-01
# 2015-02-28 2015-04-01
# 2015-03-31 2015-05-01
# 2015-04-30 2015-06-01
# 2015-05-31 2015-07-01
# 2015-06-30 2015-08-01
# 2015-07-31 2015-09-01
# 2015-08-31 2015-10-01
# 2015-09-30 2015-11-01
# 2015-10-31 2015-12-01
# 2015-11-30 2016-01-01
# 2015-12-31 2016-02-01
# 2016-01-31 2016-03-01
# 2016-02-29 2016-04-01
# 2016-03-31 2016-05-01
# 2016-04-30 2016-06-01
# 2016-05-31 2016-07-01
# 2016-06-30 2016-08-01
# 2016-07-31 2016-09-01
# 2016-08-31 2016-10-01
# 2016-09-30 2016-11-01
# 2016-10-31 2016-12-01
# 2016-11-30 2017-01-01
# 2016-12-31 2017-02-01
# 2017-01-31 2017-03-01
# 2017-02-28 2017-04-01
# 2017-03-31 2017-05-01
# 2017-04-30 2017-06-01
# 2017-05-31 2017-07-01
# 2017-06-30 2017-08-01
# 2017-07-31 2017-09-01
# 2017-08-31 2017-10-01
# 2017-09-30 2017-11-01
# 2017-10-31 2017-12-01
# 2017-11-30 2018-01-01
# 2017-12-31 2018-02-01
# 2018-01-31 2018-03-01
# 2018-02-28 2018-04-01
# 2018-03-31 2018-05-01
# 2018-04-30 2018-06-01
# Scraping Dash Data
# Starting Year: 2015 Ending Year: 2018
# 2015-03-31 2015-05-01
# 2015-04-30 2015-06-01
# 2015-05-31 2015-07-01
# 2015-06-30 2015-08-01
# 2015-07-31 2015-09-01
# 2015-08-31 2015-10-01
# 2015-09-30 2015-11-01
# 2015-10-31 2015-12-01
# 2015-11-30 2016-01-01
# 2015-12-31 2016-02-01
# 2016-01-31 2016-03-01
# 2016-02-29 2016-04-01
# 2016-03-31 2016-05-01
# 2016-04-30 2016-06-01
# 2016-05-31 2016-07-01
# 2016-06-30 2016-08-01
# 2016-07-31 2016-09-01
# 2016-08-31 2016-10-01
# 2016-09-30 2016-11-01
# 2016-10-31 2016-12-01
# 2016-11-30 2017-01-01
# 2016-12-31 2017-02-01
# 2017-01-31 2017-03-01
# 2017-02-28 2017-04-01
# 2017-03-31 2017-05-01
# 2017-04-30 2017-06-01
# 2017-05-31 2017-07-01
# 2017-06-30 2017-08-01
# 2017-07-31 2017-09-01
# 2017-08-31 2017-10-01
# 2017-09-30 2017-11-01
# 2017-10-31 2017-12-01
# 2017-11-30 2018-01-01
# 2017-12-31 2018-02-01
# 2018-01-31 2018-03-01
# 2018-02-28 2018-04-01
# 2018-03-31 2018-05-01
# 2018-04-30 2018-06-01
# Scraping Dogecoin Data
# Starting Year: 2015 Ending Year: 2018
# 2014-11-30 2015-01-01
# 2014-12-31 2015-02-01
# 2015-01-31 2015-03-01
# 2015-02-28 2015-04-01
# 2015-03-31 2015-05-01
# 2015-04-30 2015-06-01
# 2015-05-31 2015-07-01
# 2015-06-30 2015-08-01
# 2015-07-31 2015-09-01
# 2015-08-31 2015-10-01
# 2015-09-30 2015-11-01
# 2015-10-31 2015-12-01
# 2015-11-30 2016-01-01
# 2015-12-31 2016-02-01
# 2016-01-31 2016-03-01
# 2016-02-29 2016-04-01
# 2016-03-31 2016-05-01
# 2016-04-30 2016-06-01
# 2016-05-31 2016-07-01
# 2016-06-30 2016-08-01
# 2016-07-31 2016-09-01
# 2016-08-31 2016-10-01
# 2016-09-30 2016-11-01
# 2016-10-31 2016-12-01
# 2016-11-30 2017-01-01
# 2016-12-31 2017-02-01
# 2017-01-31 2017-03-01
# 2017-02-28 2017-04-01
# 2017-03-31 2017-05-01
# 2017-04-30 2017-06-01
# 2017-05-31 2017-07-01
# 2017-06-30 2017-08-01
# 2017-07-31 2017-09-01
# 2017-08-31 2017-10-01
# 2017-09-30 2017-11-01
# 2017-10-31 2017-12-01
# 2017-11-30 2018-01-01
# 2017-12-31 2018-02-01
# 2018-01-31 2018-03-01
# 2018-02-28 2018-04-01
# 2018-03-31 2018-05-01
# 2018-04-30 2018-06-01
# Scraping Ethereum Data
# Starting Year: 2015 Ending Year: 2018
# 2015-10-31 2015-12-01
# 2015-11-30 2016-01-01
# 2015-12-31 2016-02-01
# 2016-01-31 2016-03-01
# 2016-02-29 2016-04-01
# 2016-03-31 2016-05-01
# 2016-04-30 2016-06-01
# 2016-05-31 2016-07-01
# 2016-06-30 2016-08-01
# 2016-07-31 2016-09-01
# 2016-08-31 2016-10-01
# 2016-09-30 2016-11-01
# 2016-10-31 2016-12-01
# 2016-11-30 2017-01-01
# 2016-12-31 2017-02-01
# 2017-01-31 2017-03-01
# 2017-02-28 2017-04-01
# 2017-03-31 2017-05-01
# 2017-04-30 2017-06-01
# 2017-05-31 2017-07-01
# 2017-06-30 2017-08-01
# 2017-07-31 2017-09-01
# 2017-08-31 2017-10-01
# 2017-09-30 2017-11-01
# 2017-10-31 2017-12-01
# 2017-11-30 2018-01-01
# 2017-12-31 2018-02-01
# 2018-01-31 2018-03-01
# 2018-02-28 2018-04-01
# 2018-03-31 2018-05-01
# 2018-04-30 2018-06-01
# Scraping Litecoin Data
# Starting Year: 2015 Ending Year: 2018
# 2014-11-30 2015-01-01
# 2014-12-31 2015-02-01
# 2015-01-31 2015-03-01
# 2015-02-28 2015-04-01
# 2015-03-31 2015-05-01
# 2015-04-30 2015-06-01
# 2015-05-31 2015-07-01
# 2015-06-30 2015-08-01
# 2015-07-31 2015-09-01
# 2015-08-31 2015-10-01
# 2015-09-30 2015-11-01
# 2015-10-31 2015-12-01
# 2015-11-30 2016-01-01
# 2015-12-31 2016-02-01
# 2016-01-31 2016-03-01
# 2016-02-29 2016-04-01
# 2016-03-31 2016-05-01
# 2016-04-30 2016-06-01
# 2016-05-31 2016-07-01
# 2016-06-30 2016-08-01
# 2016-07-31 2016-09-01
# 2016-08-31 2016-10-01
# 2016-09-30 2016-11-01
# 2016-10-31 2016-12-01
# 2016-11-30 2017-01-01
# 2016-12-31 2017-02-01
# 2017-01-31 2017-03-01
# 2017-02-28 2017-04-01
# 2017-03-31 2017-05-01
# 2017-04-30 2017-06-01
# 2017-05-31 2017-07-01
# 2017-06-30 2017-08-01
# 2017-07-31 2017-09-01
# 2017-08-31 2017-10-01
# 2017-09-30 2017-11-01
# 2017-10-31 2017-12-01
# 2017-11-30 2018-01-01
# 2017-12-31 2018-02-01
# 2018-01-31 2018-03-01
# 2018-02-28 2018-04-01
# 2018-03-31 2018-05-01
# 2018-04-30 2018-06-01
# Scraping Monero Data
# Starting Year: 2015 Ending Year: 2018
# 2014-11-30 2015-01-01
# 2014-12-31 2015-02-01
# 2015-01-31 2015-03-01
# 2015-02-28 2015-04-01
# 2015-03-31 2015-05-01
# 2015-04-30 2015-06-01
# 2015-05-31 2015-07-01
# 2015-06-30 2015-08-01
# 2015-07-31 2015-09-01
# 2015-08-31 2015-10-01
# 2015-09-30 2015-11-01
# 2015-10-31 2015-12-01
# 2015-11-30 2016-01-01
# 2015-12-31 2016-02-01
# 2016-01-31 2016-03-01
# 2016-02-29 2016-04-01
# 2016-03-31 2016-05-01
# 2016-04-30 2016-06-01
# 2016-05-31 2016-07-01
# 2016-06-30 2016-08-01
# 2016-07-31 2016-09-01
# 2016-08-31 2016-10-01
# 2016-09-30 2016-11-01
# 2016-10-31 2016-12-01
# 2016-11-30 2017-01-01
# 2016-12-31 2017-02-01
# 2017-01-31 2017-03-01
# 2017-02-28 2017-04-01
# 2017-03-31 2017-05-01
# 2017-04-30 2017-06-01
# 2017-05-31 2017-07-01
# 2017-06-30 2017-08-01
# 2017-07-31 2017-09-01
# 2017-08-31 2017-10-01
# 2017-09-30 2017-11-01
# 2017-10-31 2017-12-01
# 2017-11-30 2018-01-01
# 2017-12-31 2018-02-01
# 2018-01-31 2018-03-01
# 2018-02-28 2018-04-01
# 2018-03-31 2018-05-01
# 2018-04-30 2018-06-01
# Scraping Ripple Data
# Starting Year: 2015 Ending Year: 2018
# 2014-11-30 2015-01-01
# 2014-12-31 2015-02-01
# 2015-01-31 2015-03-01
# 2015-02-28 2015-04-01
# 2015-03-31 2015-05-01
# 2015-04-30 2015-06-01
# 2015-05-31 2015-07-01
# 2015-06-30 2015-08-01
# 2015-07-31 2015-09-01
# 2015-08-31 2015-10-01
# 2015-09-30 2015-11-01
# 2015-10-31 2015-12-01
# 2015-11-30 2016-01-01
# 2015-12-31 2016-02-01
# 2016-01-31 2016-03-01
# 2016-02-29 2016-04-01
# 2016-03-31 2016-05-01
# 2016-04-30 2016-06-01
# 2016-05-31 2016-07-01
# 2016-06-30 2016-08-01
# 2016-07-31 2016-09-01
# 2016-08-31 2016-10-01
# 2016-09-30 2016-11-01
# 2016-10-31 2016-12-01
# 2016-11-30 2017-01-01
# 2016-12-31 2017-02-01
# 2017-01-31 2017-03-01
# 2017-02-28 2017-04-01
# 2017-03-31 2017-05-01
# 2017-04-30 2017-06-01
# 2017-05-31 2017-07-01
# 2017-06-30 2017-08-01
# 2017-07-31 2017-09-01
# 2017-08-31 2017-10-01
# 2017-09-30 2017-11-01
# 2017-10-31 2017-12-01
# 2017-11-30 2018-01-01
# 2017-12-31 2018-02-01
# 2018-01-31 2018-03-01
# 2018-02-28 2018-04-01
# 2018-03-31 2018-05-01
# 2018-04-30 2018-06-01
# Scraping Stellar Data
# Starting Year: 2015 Ending Year: 2018
# 2014-11-30 2015-01-01
# 2014-12-31 2015-02-01
# 2015-01-31 2015-03-01
# 2015-02-28 2015-04-01
# 2015-03-31 2015-05-01
# 2015-04-30 2015-06-01
# 2015-05-31 2015-07-01
# 2015-06-30 2015-08-01
# 2015-07-31 2015-09-01
# 2015-08-31 2015-10-01
# 2015-09-30 2015-11-01
# 2015-10-31 2015-12-01
# 2015-11-30 2016-01-01
# 2015-12-31 2016-02-01
# 2016-01-31 2016-03-01
# 2016-02-29 2016-04-01
# 2016-03-31 2016-05-01
# 2016-04-30 2016-06-01
# 2016-05-31 2016-07-01
# 2016-06-30 2016-08-01
# 2016-07-31 2016-09-01
# 2016-08-31 2016-10-01
# 2016-09-30 2016-11-01
# 2016-10-31 2016-12-01
# 2016-11-30 2017-01-01
# 2016-12-31 2017-02-01
# 2017-01-31 2017-03-01
# 2017-02-28 2017-04-01
# 2017-03-31 2017-05-01
# 2017-04-30 2017-06-01
# 2017-05-31 2017-07-01
# 2017-06-30 2017-08-01
# 2017-07-31 2017-09-01
# 2017-08-31 2017-10-01
# 2017-09-30 2017-11-01
# 2017-10-31 2017-12-01
# 2017-11-30 2018-01-01
# 2017-12-31 2018-02-01
# 2018-01-31 2018-03-01
# 2018-02-28 2018-04-01
# 2018-03-31 2018-05-01
# 2018-04-30 2018-06-01

# %%
def get_proxy(address):
    http_proxy  = "http://{}".format(address)
    https_proxy = "https://{}".format(address)
    ftp_proxy   = "ftp://{}".format(address)

    proxyDict = { 
                  "http"  : http_proxy, 
                  "https" : https_proxy, 
                  "ftp"   : ftp_proxy
                }
    
    return proxyDict

# %%
a = open('proxies.txt')

count = 0

proxies = []

for line in a.readlines():
    proxy = get_proxy(line.replace('\n', ''))
    proxies.append(proxy)

# %%
res = requests.get('https://whatismyip.com', proxies=proxies[0], headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36'})
