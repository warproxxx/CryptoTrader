# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/fulldata/BTCUSD.csv')

# %%
df['Time Stamp'] = df['Time Stamp'].astype(np.int64)

# %%
df = df.drop_duplicates(subset='Time Stamp')

# %%
df.reset_index(drop=True)
# Out:
#      Time Stamp            Username  \
# 0    1529999329           daaniyaan
# 1    1529999650   TheQueenOfBitcoin
# 2    1530000191          TradingSig
# 3    1530000297              danmue
# 4    1530001135               buric
# 5    1530001649        skyunlimited
# 6    1530003363         CryptoComes
# 7    1530003392         cheesetoast
# 8    1530003562              parney
# 9    1530003887             flockoo
# 10   1530004128               Godly
# 11   1530004162              DVY420
# 12   1530004200           mycotoxin
# 13   1530004688           Trade24Fx
# 14   1530004937            jegerche
# 15   1530004949          jostitrade
# 16   1530005011         crazymcdazy
# 17   1530005188         BestSignals
# 18   1530006409            TraderTQ
# 19   1530007014        CryptoLife41
# 20   1530007946        guillemtorra
# 21   1530008693       Avalontrading
# 22   1530009513                 ha2
# 23   1530010235             Alteroc
# 24   1530010877             ehurkan
# ...
