# %%
import pandas as pd

# %%
df = pd.read_csv('data/tweet/bitcoin/historic_scrape/raw/combined.csv')

# %%
df.dropna().sort_values('Likes', ascending=False).drop_duplicates('ID').sort_values('Time').reset_index(drop=True)
# Out:
#                        ID                                              Tweet  \
# 0      550441275699511296  How the tech behind Bitcoin could end up power...
# 1      550441601114574849  Vox - Bitcoin is Down 60% This Year. Here's Wh...
# 2      550442894700445696  Clarity, Coordination & Collaboration. @Circle...
# 3      550442926334296064  "Venture Capital Funding for #Bitcoin Startups...
# 4      550446277839028224  Bitcoin tips from rock legends queen "To avoid...
# 5      550446927796371456  Kinda want to tweet all the Ferengi "Rules Of ...
# 6      550447247373373440  A yr ago I was arrested & faced 30 years. Im c...
# 7      550447293824892928  Josh Garza / GAW Miners hacks Coinfire site in...
# 8      550447706661859328  NYC Wants Drivers to Pay For Parking Tickets V...
# 9      550449096259928064  Winklevoss Bitcoin Trust files to sell 20.1M s...
# 10     550449171669745664  A lot of people hate #Aries for being insensit...
# ...

# %%
df_idx = df.set_index('ID')

# %%
df_idx[df_idx.dropna().duplicated()]
# Out:
#                                                                 Tweet  \
# ID
# 564552077461188609  #Aries love with the love that is more than lo...
# 562000315151822848  #Aries will always find a way to make their lo...
# 566726412804296704        #Aries people need to keep physically busy.
# 566722091253116928  fvck you guys for pumpin' #bitcoin on Valentin...
# 569263124131540992  #Aries is the first zodiac, ruling the first h...
# 571799768944529408  You will never see an #Aries emotion of disapp...
# 569618795293216769  I do stuff. accept payment in #bitcoin or #dog...
# 562382961316995072  GetGems: The startup where social networking m...
# 570350254681227267  To love an #Aries female, dont leave anything ...
# 567813563457503232  If you manage to get close to an #Aries, then ...
# 564914470758416385  #Aries dont quit. They give head till you're red.
# 565276850231181312               #Aries need to keep physically busy.
# ...

# %%
# Out:
#                        ID                                              Tweet  \
# 0      564189695819935744  If an #Aries is pissed, don't tell them to chill.
# 1      564204798376177665  If you are friends with an #Aries, look forwar...
# 2      564211774380331008  The latest Bitcoin Price Index is 227.38 USD h...
# 3      564210883157819392  New Localbitcoins record for the Russian ruble...
# 4      564210521348788225  @EmeraldCrypto @22loops @Cryptopathic Usually ...
# 5      564210520254058496  NeuCoin Is A Bitcoin Alternative Designed For ...
# 6      564209529949523969  Blowing past #Bitcoin! Meet the woman changing...
# 7      564209194015150080  Bitcoin Price Advance Starts Small https://www...
# 8      564205976795234305  Life Inside a Secret Chinese Bitcoin Mine. "Th...
# 9      564205244792721408  How can you leverage your #bitcoin investments...
# 10     564204496931540994  You don't hear this everyday: #Bitcoin begins ...
# ...
